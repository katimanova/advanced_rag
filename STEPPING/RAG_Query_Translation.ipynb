# %% [markdown]
# ## Query Translation
#
# #### Этот этап отвечает за работу с запросом от пользователя

# %% [markdown]
# ### Библиотеки и окружения

# %%
from necessity import *

# %% [markdown]
# Варинты разбивки документов, рассмотрим 3 самые лучшие по результатам с 1 этапа

# %%
# # 1 вариант 
# splits = split_documents_html(chunk_size=1000, chunk_overlap=100)

# # 2 вариант 
# splits = split_documents_my_html()

# # 3 вариант 
# splits = split_documents_standart(chunk_size=1000, chunk_overlap=100)

# %% [markdown]
# ## Multi-Query (Мультизапросы)

# %% [markdown]
# ![structure.png](../Schemes/Multi-Query.png)

# %%
# LangSmith
os.environ["LANGCHAIN_PROJECT"] = "Query_Translation_Multi_Query_(html_split)"

# %%
# получаем смысловую разбивку всех документов
splits = split_documents_my_html()
# splits = split_documents_html(chunk_size=1000, chunk_overlap=100)
# splits = split_documents_standart(chunk_size=1000, chunk_overlap=100)

# индексируем
embeddings_model = GigaChatEmbeddings(scope="GIGACHAT_API_PERS", verify_ssl_certs=False)
db = Chroma.from_documents(documents=splits, embedding=embeddings_model)

# Устанавливаем ретриевер для поиска контекста
retriever = db.as_retriever(search_kwargs={'k': 1})

llm = GigaChat(model='GigaChat-Plus', verify_ssl_certs=False, scope="GIGACHAT_API_PERS")

# %%
# Multi Query
prompt_perspectives = ChatPromptTemplate.from_template("""Вы - ИИ ассистент. 
            Ваша задача - сгенерировать три варианта исходного вопроса для поиска в векторной базе данных.
            Задайте эти вопросы с разных точек зрения. Представьте альтернативные вопросы, разделенные новой строкой.
            Исходный вопрос: {question}""")

generate_queries = (
    prompt_perspectives 
    | llm 
    | StrOutputParser() 
    | (lambda x: x.split("\n"))
)

# список уникальных документов для контекста
def get_unique_docs(documents: list[list]):
    flattened_docs = [dumps(doc) for sublist in documents for doc in sublist]
    unique_docs = list(set(flattened_docs))
    return [loads(doc) for doc in unique_docs]

# Retrieve
# question = "Можно ли не расписываться на карте?"
retrieval_chain = generate_queries | retriever.map() | get_unique_docs
# docs = retrieval_chain.invoke({"question":question})

# %%
# RAG
prompt = ChatPromptTemplate.from_template("""Вы являетесь помощником в выполнении поиска ответов на вопросы. Используйте приведенные ниже фрагменты извлеченного контекста, чтобы ответить на вопрос. Если вы не знаете ответа, просто скажите, что вы не знаете.
        Question: {question} 
        Context: {context} 
        Answer:""")

final_rag_chain = (
    {"context": retrieval_chain, "question": RunnablePassthrough()} 
    | prompt
    | llm
    | StrOutputParser()
)

# final_rag_chain.invoke("Можно ли не расписываться на карте?")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   warn_beta(
# 'Не указано в контексте.'

# %% [markdown]
# ### Загрузка Датасета

# %%
import pandas as pd
df = pd.read_csv('../dataset.csv')

df['answer'] = df['question'].apply(lambda x: final_rag_chain.invoke(x.strip()))
display(df)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/langchain_core/_api/beta_decorator.py:87: LangChainBetaWarning: The function `loads` is in beta. It is actively being worked on, so the API may change.
#   warn_beta(
#                                              question  \
# 0                 Можно ли не расписываться на карте?
# 1   Мой друг попросил меня дать свою карту для опл...
# 2   Безопасно ли хранить пинкод в заметках в телеф...
# 3                                    Я потеряла карту
# 4   Почему при использовании карты важно не распис...
# 5   Что делать, если я потеряла телефон, на которо...
# 6   Можно ли использовать интернет-кафе и другие о...
# 7   Что делать, если я получил SMS-оповещение о оп...
# 8   Как обезопасить себя от съема данных карты в б...
# 9   Правда ли, что при бронировании гостиницы по к...
# 10  Если я из другой страны и у меня нет паспорта ...
# 11  В течении скольких дней действительна выписка ...
# 12   Нужно ли ИП указывать свой сайт для предприятия?
# 13  Может ли Банк запросить дополнительные докумен...
# 14  Какие документы нужно предоставить физическому...
# 15  Какие документы необходимо предоставить юридич...
# 16  Можно ли открыть счет индивидуальному предприн...
# 17  Какие документы потребуются, если открывать сч...
# 18  Как узнать, кто является бенефициарным владель...
# 19  Расскажи про термины 'Договор страхования' и '...
# 20  Какой минимум страховой выплаты мне вернут, ес...
# 21  При принятии пользовательских соглашений, кому...
# 22  Зачем страховщик ведет аудио и видеозапись при...
# 23  В каких случаях застрахованному могут быть опл...
# 24  Куда пользователь может направить обращение пр...
# 25  Где можно ознакомиться с дополнительной информ...
# 26  Что означает 'Партия' и вообще 'Слиток' для др...
# 27  Меня действительно должны фотографировать посл...
# 28                            Какие условия хранения?
# 29            Что такое 'Сертификат качества слитка'?
# 30  На какой срок выдается эта доверенность? Можно...
# 31  Как клиент может получить сертификат качества ...
# 32  Какие условия хранения слитков в банке? Где их...
# 33  Можно ли вернуть слиток в банк, если при получ...
# 34                  Кто может стать доверенным лицом?
# 35  Можно ли поменять доверенное лицо? Как это сде...
# 36  Как происходит покупка слитка банком? Есть ли ...
# 37  Что такое накопительный счет и как начисляются...
# 38                   Можно ли открыть вклад в 12 лет?
# 39  Могу ли я открыть несколько вкладов и пополнят...
# 40  Для получения страховой выплаты в случае несча...
# 41                      Дают ли кредит на автомобиль?
# 42  Распростроняется ли страховое покрытие на смер...
# 43  Может ли Банк изменить Тарифный план по кредит...
# 44  Можно ли внести частичное досрочное погашение ...
# 45  Что будет в случае просрочки платежа по кредит...
# 46  Можно ли на время приостановить выплаты по кре...
# 47  Я хочу оформить дополнительную карту на супруг...
# 48  А что если я потеряю карту? Сколько у меня ест...
# 49  Прочитал тут у вас про блокировку карточки. А ...
# 50  А есть ли какие-то льготные условия, если я за...
# 51  Какие процедуры предусмотрены банком для обраб...
# 52       Что происходит с депозитами в случае смерти?
# 53  Могу я отказаться от получения уведомлений от ...
# 54  Как я могу увеличить лимит по своей кредитной ...
# 55  Каковы условия отмены банковской операции, нап...
# 56  Какие услуги доступны клиентам через Интернет-...
# 57  Я не пользовалась кредиткой год, но у меня там...
#
#                                              contexts  \
# 0   ['После получения карты поставьте свою подпись...
# 1   ['Никогда не принимайте рекомендации, советы, ...
# 2   ['Категорически запрещается записывать ПИН-код...
# 3   [' Вы потеряли карту или ее украли\nПрежде все...
# 4   ['Проверяйте правильность суммы, указанной на ...
# 5   ['При утрате Мобильного телефона, используемог...
# 6   ['Избегайте осуществления Интернет-операций с ...
# 7   ['Если Вы уверены, что операция не могла быть ...
# 8   ['Поэтому, при пользовании банкоматом не ленит...
# 9   ['При бронировании номера в гостинице по карте...
# 10  ['\n                     1. Документы и сведен...
# 11  ['\n                    2.2. Выписка из Единог...
# 12  ['\n                    3. Документы и сведени...
# 13  ['\n                     26. Банк может запрос...
# 14  ['1. Документы и сведения, получаемые в целях ...
# 15  ['2.1. Учредительные документы юридического ли...
# 16  ['3.1. Идентификация индивидуального предприни...
# 17  ['5.1. Документ, удостоверяющий личность и ука...
# 18  ['12. Идентификация бенефициарного(ых) владель...
# 19  ['1. Термины и определения     \n             ...
# 20   \n                    2.19.   При добровольно...
# 21  ['\n                    5. Персональные данные...
# 22  ['При заключении Договоров страхования, а такж...
# 23  ['По договорам добровольного страхования непре...
# 24  ['При возникновении вопросов или спора можно о...
# 25  ['Дополнительная информация и документы о деят...
# 26  ['\n                    Партия — приобретенные...
# 27  ['\n                    2.13.12. После подтвер...
# 28  [' \n                    2.14.9. Условия хране...
# 29  ['Сертификат качества слитка — документ о каче...
# 30  ['Датой выдачи доверенности считается дата пре...
# 31  ['По требованию Клиента Банк предоставляет Кли...
# 32  ['Хранение Банком Слитка Клиента осуществляетс...
# 33  ['В случае обнаружения при приеме Слитка с отв...
# 34  ['Доверенное лицо — физическое лицо, уполномоч...
# 35  ['Клиент может отменить выданную доверенность ...
# 36  ['Банк приобретает у Клиента только Слитки, на...
# 37  ['\n                    3.1. Начисление процен...
# 38  ['1.2. Банк не заключает Договор вклада (Догов...
# 39  ['\n                    4.1. Клиент имеет прав...
# 40  ['\n                    6.1. По риску Смерть в...
# 41  ['3.1. Банк предоставляет Клиенту Кредит на по...
# 42  [' \n                    Страховое покрытие по...
# 43  ['\n                    Банк вправе в одностор...
# 44  ['«Клиент имеет право досрочно погасить Задолж...
# 45  ['«В случае неоплаты платежа Клиент должен упл...
# 46  ['«На основании обращения Клиента и по согласо...
# 47  ['«3.2. По заявлению Клиента, переданному в Ба...
# 48  ['«6.1. При обнаружении утери, кражи или порчи...
# 49  ['«6.1. [...] а также в случае изъятия Кредитн...
# 50  ['«5.15. На основании обращения Клиента и по с...
# 51  ['Банк имеет установленные процедуры для обраб...
# 52  ['В случае смерти клиента банк замораживает де...
# 53  ['Клиенты имеют право отказаться от получения ...
# 54  ['Для увеличения кредитного лимита клиенты дол...
# 55  ['Клиенты могут отменить определенные банковск...
# 56  ['Через Интернет-банк клиенты могут управлять ...
# 57  ['"8. Расторжение Договора кредитной карты\n  ...
#
#                                          ground_truth  \
# 0   При отсутствии подписи карта может быть не при...
# 1   Не передавайте карту другим лицам, в т.ч. родс...
# 2   Да, однако не указывайте в названии заметки, ч...
# 3   Если вы не уверены, что карту украли, не спеши...
# 4   Важно проверять правильность суммы перед подпи...
# 5   Если вы потеряли телефон с установленным мобил...
# 6   Нет, не рекомендуется использовать интернет-ка...
# 7   Если вы получили SMS-оповещение о операции, ко...
# 8   Чтобы обезопасить себя от съема данных карты в...
# 9   Нет, неправда. При бронировании гостиницы по к...
# 10  \n                        Если вы из другой ст...
# 11  Выписка из Единого государственного реестра юр...
# 12  Да, индивидуальному предпринимателю необходимо...
# 13  Да, Банк может запросить у Вас дополнительные ...
# 14  Физическому лицу для открытия счета необходимо...
# 15  Юридическому лицу необходимо предоставить учре...
# 16  Да, индивидуальному предпринимателю-иностранно...
# 17  Для открытия счета нотариусу, занимающемуся ча...
# 18  Для идентификации бенефициарного владельца юри...
# 19   Да, конечно! Договор страхования — это догово...
# 20   \n                    Минимальная страховая в...
# 21  \n                    Согласно пункту 5.1 поль...
# 22  Страховщик ведет аудио, видеозапись, фотографи...
# 23  По договорам добровольного страхования непредв...
# 24  При возникновении вопросов или спора с АО 'Тин...
# 25  Дополнительная информация и документы о деятел...
# 26  Давайте разберемся! \n                    Парт...
# 27  Да, Вас действительно должнен сфотографировать...
# 28  \n                    В соответсвии с пунктом ...
# 29  Сертификат качества слитка - это документ, выд...
# 30  Доверенность выдается сроком на 1 год. Полномо...
# 31  По требованию клиента банк предоставляет ему з...
# 32  Слитки хранятся в специальном хранилище 5 клас...
# 33  Да, если при получении слитка с хранения были ...
# 34  Доверенным лицом клиента может стать любое физ...
# 35  Да, клиент может отменить ранее выданную довер...
# 36  Банк осуществляет покупку слитков драгоценных ...
# 37  \n                    Накопительный счет - это...
# 38  Нет, Банк не заключает договор вклада с лицами...
# 39   \n                    Да, вы можете открыть н...
# 40  Да, в таком случае необходимы справки из психо...
# 41  Да, в соответсвии с пунктом 3.1. Банк предоста...
# 42  Нет, страховое покрытие не распространяется на...
# 43  Да, Банк может изменить Тарифный план по креди...
# 44  Да, Клиент имеет право совершить частичное дос...
# 45  В случае неоплаты минимального платежа по кред...
# 46  Да, на основании обращения Клиента и по соглас...
# 47  Вы можете оформить дополнительную кредитную ка...
# 48  В случае утери или кражи кредитной карты, вы д...
# 49  Если вы забыли карту в банкомате, вам необходи...
# 50  Да, в документе указано, что по обращению клие...
# 51  Банк следует четко установленным процедурам дл...
# 52  После смерти клиента банк замораживает все его...
# 53  Клиенты могут отказаться от получения определе...
# 54  Чтобы увеличить кредитный лимит, клиентам необ...
# 55  Условия отмены банковской операции зависят от ...
# 56  Интернет-банк предоставляет клиентам возможнос...
# 57  Согласно пунуту 8.6 - вы не можете вернуть ваш...
#
#                                                answer
# 0                             Не указано в контексте.
# 1   Да, это может быть опасно. Мошенники могут исп...
# 2   Нет, не безопасно хранить пинкод в заметках в ...
# 3   Если вы потеряли карту, вам следует обратиться...
# 4   Важно не расписываться на квитанциях/чеках до ...
# 5   Если вы потеряли телефон, на котором было уста...
# 6   Нет, не рекомендуется использовать интернет-ка...
# 7   Если вы получили SMS-оповещение о операции по ...
# 8   Два способа обезопасить себя от съема данных к...
# 9   При бронировании гостиницы по карте вам потреб...
# 10  Если вы являетесь иностранным гражданином и у ...
# 11  Выписка из ЕГРЮЛ действительна в течение 30 ка...
# 12                   Я не знаю ответа на этот вопрос.
# 13  Да, Банк может запросить у Клиента дополнитель...
# 14  Для открытия счета физическому лицу необходимо...
# 15  Для открытия счета в Банке юридическому лицу н...
# 16  Да, согласно представленному контексту, индиви...
# 17  Для открытия счета для нотариуса, занимающегос...
# 18  Для того чтобы узнать, кто является бенефициар...
# 19  Термин "Договор страхования" относится к согла...
# 20  Я не могу ответить на этот вопрос, так как кон...
# 21  Мои данные могут попасть не только банку, но и...
# 22  Страховщик ведет аудио и видеозапись при взаим...
# 23  Застрахованному могут быть оплачены планируемы...
# 24  Пользователь может направить обращение при воз...
# 25  Дополнительную информацию и документы о деятел...
# 26  Партия - это приобретенные Клиентом Слитки в к...
# 27  Да, после подписания акта приема-передачи пред...
# 28                   Я не знаю ответа на этот вопрос.
# 29  Сертификат качества слитка - это документ, кот...
# 30  Из предоставленного контекста невозможно опред...
# 31  По требованию клиента банк предоставляет клиен...
# 32  Слитки хранятся в хранилище 5 (Пятого) класса ...
# 33  Да, согласно представленному контексту, если п...
# 34  Из предоставленного контекста нельзя однозначн...
# 35  Из представленного контекста нельзя однозначно...
# 36  Банк приобретает слитки у клиента, которые нах...
# 37  Накопительный счет - это банковский продукт, к...
# 38  Нет, согласно представленному контексту, Банк ...
# 39  Да, согласно представленному контексту, клиент...
# 40  Нет, справка из психушки не требуется для полу...
# 41  Да, в тексте упоминается, что банк обязуется п...
# 42  Да, страховое покрытие не распространяется на ...
# 43  Да, Банк может изменить Тарифный план по креди...
# 44  Да, согласно представленному контексту, можно ...
# 45  Из предоставленного контекста невозможно точно...
# 46  Да, на основании обращения клиента и по соглас...
# 47  Да, ваша супруга будет иметь доступ к общему л...
# 48  Чтобы заблокировать карту, вам нужно связаться...
# 49  Если карта была удержана банкоматом, вам следу...
# 50  Да, согласно условиям программы "Рассрочка", Б...
# 51  Из представленных фрагментов контекста невозмо...
# 52  В случае смерти депозиты могут быть выплачены ...
# 53  Вы можете отказаться от получения уведомлений ...
# 54  Из предоставленного контекста нельзя однозначн...
# 55  Из предоставленного контекста нельзя однозначн...
# 56  Через Интернет-банк клиентам доступны следующи...
# 57  Не зная конкретного контекста вопроса, сложно ...

# %%
df.to_csv('../rag_answer/rag_step_query_translation/rag_multi_query.csv', index=False)

# %% [markdown]
# ## RAG-Fusion

# %% [markdown]
# ![structure.png](../Schemes/Rag-Fusion.png)

# %%
# LangSmith
os.environ["LANGCHAIN_PROJECT"] = "Query_Translation_RAG_Fusion"

# %%
prompt_rag_fusion = ChatPromptTemplate.from_template("""
                        Вы - полезный помощник, который генерирует несколько поисковых запросов на основе одного входного запроса. \n
                        Сгенерируйте несколько поисковых запросов, связанных с: {question}.
                        Постарайтесь как будто разложить исохдный вопрос на более простые вопросы.\n 
                        Output (3 queries): \n""")

generate_queries_fusion = (
    prompt_rag_fusion |
    llm |
    StrOutputParser() |
    (lambda x: x.split("\n"))
)

# ранжирование документов (метод обратного ранжирования)
def reciprocal_rank_fusion(results: list[list], k=60):
    fused_scores = {}
    for docs in results:
        # Assumes the docs are returned in sorted order of relevance
        for rank, doc in enumerate(docs):
            doc_str = dumps(doc)
            if doc_str not in fused_scores:
                fused_scores[doc_str] = 0
            previous_score = fused_scores[doc_str]
            fused_scores[doc_str] += 1 / (rank + k)

    reranked_results = [
        (loads(doc), score)
        for doc, score in sorted(fused_scores.items(), key=lambda x: x[1], reverse=True)
    ]
    return reranked_results

chain_fusion = generate_queries_fusion | retriever.map() | reciprocal_rank_fusion

# %%
# RAG
prompt = ChatPromptTemplate.from_template("""Вы являетесь помощником в выполнении поиска ответов на вопросы. Используйте приведенные ниже фрагменты извлеченного контекста, чтобы ответить на вопрос. Если вы не знаете ответа, просто скажите, что вы не знаете.
        Question: {question} 
        Context: {context} 
        Answer:""")

final_rag_fusion_chain = (
    {"context": chain_fusion, "question": RunnablePassthrough()} 
    | prompt
    | llm
    | StrOutputParser()
)

# %% [markdown]
# ### Загрузка Датасета

# %%
import pandas as pd
df = pd.read_csv('../dataset.csv')

df['answer'] = df['question'].apply(lambda x: final_rag_fusion_chain.invoke(x.strip()))
display(df)
# Out:
# Failed to batch ingest runs: LangSmithError("Failed to post https://api.smith.langchain.com/runs/batch in LangSmith API. HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Read timed out. (read timeout=10.0)\n")
#                                              question  \
# 0                 Можно ли не расписываться на карте?
# 1   Мой друг попросил меня дать свою карту для опл...
# 2   Безопасно ли хранить пинкод в заметках в телеф...
# 3                                    Я потеряла карту
# 4   Почему при использовании карты важно не распис...
# 5   Что делать, если я потеряла телефон, на которо...
# 6   Можно ли использовать интернет-кафе и другие о...
# 7   Что делать, если я получил SMS-оповещение о оп...
# 8   Как обезопасить себя от съема данных карты в б...
# 9   Правда ли, что при бронировании гостиницы по к...
# 10  Если я из другой страны и у меня нет паспорта ...
# 11  В течении скольких дней действительна выписка ...
# 12   Нужно ли ИП указывать свой сайт для предприятия?
# 13  Может ли Банк запросить дополнительные докумен...
# 14  Какие документы нужно предоставить физическому...
# 15  Какие документы необходимо предоставить юридич...
# 16  Можно ли открыть счет индивидуальному предприн...
# 17  Какие документы потребуются, если открывать сч...
# 18  Как узнать, кто является бенефициарным владель...
# 19  Расскажи про термины 'Договор страхования' и '...
# 20  Какой минимум страховой выплаты мне вернут, ес...
# 21  При принятии пользовательских соглашений, кому...
# 22  Зачем страховщик ведет аудио и видеозапись при...
# 23  В каких случаях застрахованному могут быть опл...
# 24  Куда пользователь может направить обращение пр...
# 25  Где можно ознакомиться с дополнительной информ...
# 26  Что означает 'Партия' и вообще 'Слиток' для др...
# 27  Меня действительно должны фотографировать посл...
# 28                            Какие условия хранения?
# 29            Что такое 'Сертификат качества слитка'?
# 30  На какой срок выдается эта доверенность? Можно...
# 31  Как клиент может получить сертификат качества ...
# 32  Какие условия хранения слитков в банке? Где их...
# 33  Можно ли вернуть слиток в банк, если при получ...
# 34                  Кто может стать доверенным лицом?
# 35  Можно ли поменять доверенное лицо? Как это сде...
# 36  Как происходит покупка слитка банком? Есть ли ...
# 37  Что такое накопительный счет и как начисляются...
# 38                   Можно ли открыть вклад в 12 лет?
# 39  Могу ли я открыть несколько вкладов и пополнят...
# 40  Для получения страховой выплаты в случае несча...
# 41                      Дают ли кредит на автомобиль?
# 42  Распростроняется ли страховое покрытие на смер...
# 43  Может ли Банк изменить Тарифный план по кредит...
# 44  Можно ли внести частичное досрочное погашение ...
# 45  Что будет в случае просрочки платежа по кредит...
# 46  Можно ли на время приостановить выплаты по кре...
# 47  Я хочу оформить дополнительную карту на супруг...
# 48  А что если я потеряю карту? Сколько у меня ест...
# 49  Прочитал тут у вас про блокировку карточки. А ...
# 50  А есть ли какие-то льготные условия, если я за...
# 51  Какие процедуры предусмотрены банком для обраб...
# 52       Что происходит с депозитами в случае смерти?
# 53  Могу я отказаться от получения уведомлений от ...
# 54  Как я могу увеличить лимит по своей кредитной ...
# 55  Каковы условия отмены банковской операции, нап...
# 56  Какие услуги доступны клиентам через Интернет-...
# 57  Я не пользовалась кредиткой год, но у меня там...
#
#                                              contexts  \
# 0   ['После получения карты поставьте свою подпись...
# 1   ['Никогда не принимайте рекомендации, советы, ...
# 2   ['Категорически запрещается записывать ПИН-код...
# 3   [' Вы потеряли карту или ее украли\nПрежде все...
# 4   ['Проверяйте правильность суммы, указанной на ...
# 5   ['При утрате Мобильного телефона, используемог...
# 6   ['Избегайте осуществления Интернет-операций с ...
# 7   ['Если Вы уверены, что операция не могла быть ...
# 8   ['Поэтому, при пользовании банкоматом не ленит...
# 9   ['При бронировании номера в гостинице по карте...
# 10  ['\n                     1. Документы и сведен...
# 11  ['\n                    2.2. Выписка из Единог...
# 12  ['\n                    3. Документы и сведени...
# 13  ['\n                     26. Банк может запрос...
# 14  ['1. Документы и сведения, получаемые в целях ...
# 15  ['2.1. Учредительные документы юридического ли...
# 16  ['3.1. Идентификация индивидуального предприни...
# 17  ['5.1. Документ, удостоверяющий личность и ука...
# 18  ['12. Идентификация бенефициарного(ых) владель...
# 19  ['1. Термины и определения     \n             ...
# 20   \n                    2.19.   При добровольно...
# 21  ['\n                    5. Персональные данные...
# 22  ['При заключении Договоров страхования, а такж...
# 23  ['По договорам добровольного страхования непре...
# 24  ['При возникновении вопросов или спора можно о...
# 25  ['Дополнительная информация и документы о деят...
# 26  ['\n                    Партия — приобретенные...
# 27  ['\n                    2.13.12. После подтвер...
# 28  [' \n                    2.14.9. Условия хране...
# 29  ['Сертификат качества слитка — документ о каче...
# 30  ['Датой выдачи доверенности считается дата пре...
# 31  ['По требованию Клиента Банк предоставляет Кли...
# 32  ['Хранение Банком Слитка Клиента осуществляетс...
# 33  ['В случае обнаружения при приеме Слитка с отв...
# 34  ['Доверенное лицо — физическое лицо, уполномоч...
# 35  ['Клиент может отменить выданную доверенность ...
# 36  ['Банк приобретает у Клиента только Слитки, на...
# 37  ['\n                    3.1. Начисление процен...
# 38  ['1.2. Банк не заключает Договор вклада (Догов...
# 39  ['\n                    4.1. Клиент имеет прав...
# 40  ['\n                    6.1. По риску Смерть в...
# 41  ['3.1. Банк предоставляет Клиенту Кредит на по...
# 42  [' \n                    Страховое покрытие по...
# 43  ['\n                    Банк вправе в одностор...
# 44  ['«Клиент имеет право досрочно погасить Задолж...
# 45  ['«В случае неоплаты платежа Клиент должен упл...
# 46  ['«На основании обращения Клиента и по согласо...
# 47  ['«3.2. По заявлению Клиента, переданному в Ба...
# 48  ['«6.1. При обнаружении утери, кражи или порчи...
# 49  ['«6.1. [...] а также в случае изъятия Кредитн...
# 50  ['«5.15. На основании обращения Клиента и по с...
# 51  ['Банк имеет установленные процедуры для обраб...
# 52  ['В случае смерти клиента банк замораживает де...
# 53  ['Клиенты имеют право отказаться от получения ...
# 54  ['Для увеличения кредитного лимита клиенты дол...
# 55  ['Клиенты могут отменить определенные банковск...
# 56  ['Через Интернет-банк клиенты могут управлять ...
# 57  ['"8. Расторжение Договора кредитной карты\n  ...
#
#                                          ground_truth  \
# 0   При отсутствии подписи карта может быть не при...
# 1   Не передавайте карту другим лицам, в т.ч. родс...
# 2   Да, однако не указывайте в названии заметки, ч...
# 3   Если вы не уверены, что карту украли, не спеши...
# 4   Важно проверять правильность суммы перед подпи...
# 5   Если вы потеряли телефон с установленным мобил...
# 6   Нет, не рекомендуется использовать интернет-ка...
# 7   Если вы получили SMS-оповещение о операции, ко...
# 8   Чтобы обезопасить себя от съема данных карты в...
# 9   Нет, неправда. При бронировании гостиницы по к...
# 10  \n                        Если вы из другой ст...
# 11  Выписка из Единого государственного реестра юр...
# 12  Да, индивидуальному предпринимателю необходимо...
# 13  Да, Банк может запросить у Вас дополнительные ...
# 14  Физическому лицу для открытия счета необходимо...
# 15  Юридическому лицу необходимо предоставить учре...
# 16  Да, индивидуальному предпринимателю-иностранно...
# 17  Для открытия счета нотариусу, занимающемуся ча...
# 18  Для идентификации бенефициарного владельца юри...
# 19   Да, конечно! Договор страхования — это догово...
# 20   \n                    Минимальная страховая в...
# 21  \n                    Согласно пункту 5.1 поль...
# 22  Страховщик ведет аудио, видеозапись, фотографи...
# 23  По договорам добровольного страхования непредв...
# 24  При возникновении вопросов или спора с АО 'Тин...
# 25  Дополнительная информация и документы о деятел...
# 26  Давайте разберемся! \n                    Парт...
# 27  Да, Вас действительно должнен сфотографировать...
# 28  \n                    В соответсвии с пунктом ...
# 29  Сертификат качества слитка - это документ, выд...
# 30  Доверенность выдается сроком на 1 год. Полномо...
# 31  По требованию клиента банк предоставляет ему з...
# 32  Слитки хранятся в специальном хранилище 5 клас...
# 33  Да, если при получении слитка с хранения были ...
# 34  Доверенным лицом клиента может стать любое физ...
# 35  Да, клиент может отменить ранее выданную довер...
# 36  Банк осуществляет покупку слитков драгоценных ...
# 37  \n                    Накопительный счет - это...
# 38  Нет, Банк не заключает договор вклада с лицами...
# 39   \n                    Да, вы можете открыть н...
# 40  Да, в таком случае необходимы справки из психо...
# 41  Да, в соответсвии с пунктом 3.1. Банк предоста...
# 42  Нет, страховое покрытие не распространяется на...
# 43  Да, Банк может изменить Тарифный план по креди...
# 44  Да, Клиент имеет право совершить частичное дос...
# 45  В случае неоплаты минимального платежа по кред...
# 46  Да, на основании обращения Клиента и по соглас...
# 47  Вы можете оформить дополнительную кредитную ка...
# 48  В случае утери или кражи кредитной карты, вы д...
# 49  Если вы забыли карту в банкомате, вам необходи...
# 50  Да, в документе указано, что по обращению клие...
# 51  Банк следует четко установленным процедурам дл...
# 52  После смерти клиента банк замораживает все его...
# 53  Клиенты могут отказаться от получения определе...
# 54  Чтобы увеличить кредитный лимит, клиентам необ...
# 55  Условия отмены банковской операции зависят от ...
# 56  Интернет-банк предоставляет клиентам возможнос...
# 57  Согласно пунуту 8.6 - вы не можете вернуть ваш...
#
#                                                answer
# 0                             Не указано в контексте.
# 1   Да, передавать свою карту другому человеку для...
# 2   Нет, не безопасно хранить пинкод в заметках в ...
# 3   Если вы потеряли карту, вам следует немедленно...
# 4   Подписывая квитанции или чеки до проверки прав...
# 5   Если вы потеряли телефон, на котором было уста...
# 6   Нет, не рекомендуется использовать интернет-ка...
# 7   Если вы получили SMS-оповещение о операции по ...
# 8   Для защиты вашей карты от съема данных злоумыш...
# 9   Нет, при бронировании гостиницы по карте вам н...
# 10  Я не знаю ответа на этот вопрос. Пожалуйста, у...
# 11  Выписка из ЕГРЮЛ считается действительной для ...
# 12  В контексте нет информации о том, нужно ли ИП ...
# 13  Да, банк может запросить у клиента дополнитель...
# 14  Для открытия счета физическому лицу необходимо...
# 15  Для открытия счета в Банке юридическому лицу н...
# 16  Из предоставленного контекста нельзя однозначн...
# 17  Для открытия счета нотариусу, занимающемуся ча...
# 18  Идентификация бенефициарных владельцев может о...
# 19  Термин "Договор страхования" относится к юриди...
# 20  Я не могу ответить на этот вопрос, так как тек...
# 21  Данные пользователя могут быть переданы третьи...
# 22  Страховщик ведет аудио и видеозапись при взаим...
# 23  Застрахованному могут быть оплачены планируемы...
# 24  Пользователь может направить обращение при воз...
# 25  Дополнительную информацию и документы о деятел...
# 26  Партия и Слиток в контексте драгоценных металл...
# 27  Да, после подписания акта приема-передачи пред...
# 28  Условия хранения включают температуру воздуха ...
# 29  Сертификат качества слитка - это документ, кот...
# 30  Из предоставленного контекста невозможно точно...
# 31  Клиент может получить сертификат качества слит...
# 32  Слитки хранятся в хранилище 5 (Пятого) класса ...
# 33  Да, согласно представленному контексту, повреж...
# 34  Доверенным лицом может стать любое физическое ...
# 35  Из предоставленного контекста нельзя однозначн...
# 36  Банк приобретает у клиента только слитки, нахо...
# 37  Накопительный счет - это вид банковского счета...
# 38  Нет, согласно представленным фрагментам контек...
# 39  Да, вы можете открыть несколько вкладов и попо...
# 40  Нет, справка из психушки не требуется для полу...
# 41  Да, кредит на автомобиль может быть предоставлен.
# 42  Да, страховое покрытие не распространяется на ...
# 43  Да, Банк может изменить Тарифный план по креди...
# 44  Да, можно внести частичное досрочное погашение...
# 45  В случае просрочки платежа по кредиту могут бы...
# 46  Да, на основании обращения клиента и согласова...
# 47  Для оформления дополнительной карты на супругу...
# 48  Для блокировки карты необходимо связаться с ба...
# 49  Если вы забыли забрать свою карточку в банкома...
# 50  Да, согласно условиям программы "Рассрочка", н...
# 51  Банк предусматривает следующие процедуры для о...
# 52  В случае смерти депозиты могут быть выплачены ...
# 53  Вы можете отказаться от получения уведомлений ...
# 54  Вы можете увеличить лимит по своей кредитной к...
# 55  Условия отмены банковской операции, например, ...
# 56  Через Интернет-банк клиентам доступны следующи...
# 57  Вы можете вернуть свои 800 рублей, которые ост...

# %%
df.to_csv('../rag_answer/rag_step_query_translation/rag_fusion.csv', index=False)

# %% [markdown]
# ## Step-back

# %% [markdown]
# ![structure.png](../Schemes/Step_back.png)

# %%
# LangSmith
os.environ["LANGCHAIN_PROJECT"] = "Query_Translation_Step_back_(my_html_split)"

# %%
# Few Shot примеры
from langchain_core.prompts import ChatPromptTemplate, FewShotChatMessagePromptTemplate

examples = [
    {
        "input": "Нужно ли ИП указывать свой сайт для предприятия?",
        "output": "Что необходимо предоставить ИП?",
    },
    {
        "input": "Я не пользовалась кредиткой год, но у меня там лежат мои 800 рублей, я могу их как-то вернуть?",
        "output": "Что будет при неиспользовании кредитной карты?",
    },
    {
        "input": "Дают ли кредит на автомобиль?",
        "output": "На что дают кредит?",
    },
    {
        "input": "Распростроняется ли страховое покрытие на смерть в алкогольном опьянении?",
        "output": "На что не распространяется страховое покрытие по риску 'Смерть'?",
    },
]

example_prompt = ChatPromptTemplate.from_messages(
    [
        ("human", "{input}"),
        ("ai", "{output}"),
    ]
)
few_shot_prompt = FewShotChatMessagePromptTemplate(
    example_prompt=example_prompt,
    examples=examples,
)

# промт из статьи 
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            """Вы являетесь экспертом в области мировых знаний. Ваша задача - сделать шаг назад и перефразировать вопрос в более общий, на который проще ответить.
               Вот несколько примеров:""",
        ),
        few_shot_prompt,
        # исходный вопрос
        ("user", "{question}"),
    ]
)

generate_queries_step_back = prompt | llm | StrOutputParser()

# %%
prompt = ChatPromptTemplate.from_template("""
    Вы являетесь экспертом в области знаний пользовательских соглашений для банка Tinkoff и помогаете отвечать на вопросы.\n
    Я собираюсь задать вам вопрос. Ваш ответ должен быть исчерпывающим и не противоречить следующему контексту, если он уместен.
    В противном случае, игнорируйте его, если он неуместен.

    # {normal_context}
    # {step_back_context}

    # Original Question: {question}
    # Answer:
""")

chain = (
    {
        # Retrieve context using the normal question
        "normal_context": RunnableLambda(lambda x: x["question"]) | retriever,
        # Retrieve context using the step-back question
        "step_back_context": generate_queries_step_back | retriever,
        # Pass on the question
        "question": lambda x: x["question"],
    }
    | prompt
    | llm
    | StrOutputParser()
)

# %%
# chain.invoke({"question": 'Можно ли не расписываться на карте?'})

# %% [markdown]
# ### Загрузка Датасета

# %%
import pandas as pd
df = pd.read_csv('../dataset.csv')

df['answer'] = df['question'].apply(lambda x: chain.invoke({"question": x.strip()}))
display(df)
# Out:
# Failed to batch ingest runs: LangSmithError("Failed to post https://api.smith.langchain.com/runs/batch in LangSmith API. HTTPSConnectionPool(host='api.smith.langchain.com', port=443): Read timed out. (read timeout=10.0)\n")
#                                              question  \
# 0                 Можно ли не расписываться на карте?
# 1   Мой друг попросил меня дать свою карту для опл...
# 2   Безопасно ли хранить пинкод в заметках в телеф...
# 3                                    Я потеряла карту
# 4   Почему при использовании карты важно не распис...
# 5   Что делать, если я потеряла телефон, на которо...
# 6   Можно ли использовать интернет-кафе и другие о...
# 7   Что делать, если я получил SMS-оповещение о оп...
# 8   Как обезопасить себя от съема данных карты в б...
# 9   Правда ли, что при бронировании гостиницы по к...
# 10  Если я из другой страны и у меня нет паспорта ...
# 11  В течении скольких дней действительна выписка ...
# 12   Нужно ли ИП указывать свой сайт для предприятия?
# 13  Может ли Банк запросить дополнительные докумен...
# 14  Какие документы нужно предоставить физическому...
# 15  Какие документы необходимо предоставить юридич...
# 16  Можно ли открыть счет индивидуальному предприн...
# 17  Какие документы потребуются, если открывать сч...
# 18  Как узнать, кто является бенефициарным владель...
# 19  Расскажи про термины 'Договор страхования' и '...
# 20  Какой минимум страховой выплаты мне вернут, ес...
# 21  При принятии пользовательских соглашений, кому...
# 22  Зачем страховщик ведет аудио и видеозапись при...
# 23  В каких случаях застрахованному могут быть опл...
# 24  Куда пользователь может направить обращение пр...
# 25  Где можно ознакомиться с дополнительной информ...
# 26  Что означает 'Партия' и вообще 'Слиток' для др...
# 27  Меня действительно должны фотографировать посл...
# 28                            Какие условия хранения?
# 29            Что такое 'Сертификат качества слитка'?
# 30  На какой срок выдается эта доверенность? Можно...
# 31  Как клиент может получить сертификат качества ...
# 32  Какие условия хранения слитков в банке? Где их...
# 33  Можно ли вернуть слиток в банк, если при получ...
# 34                  Кто может стать доверенным лицом?
# 35  Можно ли поменять доверенное лицо? Как это сде...
# 36  Как происходит покупка слитка банком? Есть ли ...
# 37  Что такое накопительный счет и как начисляются...
# 38                   Можно ли открыть вклад в 12 лет?
# 39  Могу ли я открыть несколько вкладов и пополнят...
# 40  Для получения страховой выплаты в случае несча...
# 41                      Дают ли кредит на автомобиль?
# 42  Распростроняется ли страховое покрытие на смер...
# 43  Может ли Банк изменить Тарифный план по кредит...
# 44  Можно ли внести частичное досрочное погашение ...
# 45  Что будет в случае просрочки платежа по кредит...
# 46  Можно ли на время приостановить выплаты по кре...
# 47  Я хочу оформить дополнительную карту на супруг...
# 48  А что если я потеряю карту? Сколько у меня ест...
# 49  Прочитал тут у вас про блокировку карточки. А ...
# 50  А есть ли какие-то льготные условия, если я за...
# 51  Какие процедуры предусмотрены банком для обраб...
# 52       Что происходит с депозитами в случае смерти?
# 53  Могу я отказаться от получения уведомлений от ...
# 54  Как я могу увеличить лимит по своей кредитной ...
# 55  Каковы условия отмены банковской операции, нап...
# 56  Какие услуги доступны клиентам через Интернет-...
# 57  Я не пользовалась кредиткой год, но у меня там...
#
#                                              contexts  \
# 0   ['После получения карты поставьте свою подпись...
# 1   ['Никогда не принимайте рекомендации, советы, ...
# 2   ['Категорически запрещается записывать ПИН-код...
# 3   [' Вы потеряли карту или ее украли\nПрежде все...
# 4   ['Проверяйте правильность суммы, указанной на ...
# 5   ['При утрате Мобильного телефона, используемог...
# 6   ['Избегайте осуществления Интернет-операций с ...
# 7   ['Если Вы уверены, что операция не могла быть ...
# 8   ['Поэтому, при пользовании банкоматом не ленит...
# 9   ['При бронировании номера в гостинице по карте...
# 10  ['\n                     1. Документы и сведен...
# 11  ['\n                    2.2. Выписка из Единог...
# 12  ['\n                    3. Документы и сведени...
# 13  ['\n                     26. Банк может запрос...
# 14  ['1. Документы и сведения, получаемые в целях ...
# 15  ['2.1. Учредительные документы юридического ли...
# 16  ['3.1. Идентификация индивидуального предприни...
# 17  ['5.1. Документ, удостоверяющий личность и ука...
# 18  ['12. Идентификация бенефициарного(ых) владель...
# 19  ['1. Термины и определения     \n             ...
# 20   \n                    2.19.   При добровольно...
# 21  ['\n                    5. Персональные данные...
# 22  ['При заключении Договоров страхования, а такж...
# 23  ['По договорам добровольного страхования непре...
# 24  ['При возникновении вопросов или спора можно о...
# 25  ['Дополнительная информация и документы о деят...
# 26  ['\n                    Партия — приобретенные...
# 27  ['\n                    2.13.12. После подтвер...
# 28  [' \n                    2.14.9. Условия хране...
# 29  ['Сертификат качества слитка — документ о каче...
# 30  ['Датой выдачи доверенности считается дата пре...
# 31  ['По требованию Клиента Банк предоставляет Кли...
# 32  ['Хранение Банком Слитка Клиента осуществляетс...
# 33  ['В случае обнаружения при приеме Слитка с отв...
# 34  ['Доверенное лицо — физическое лицо, уполномоч...
# 35  ['Клиент может отменить выданную доверенность ...
# 36  ['Банк приобретает у Клиента только Слитки, на...
# 37  ['\n                    3.1. Начисление процен...
# 38  ['1.2. Банк не заключает Договор вклада (Догов...
# 39  ['\n                    4.1. Клиент имеет прав...
# 40  ['\n                    6.1. По риску Смерть в...
# 41  ['3.1. Банк предоставляет Клиенту Кредит на по...
# 42  [' \n                    Страховое покрытие по...
# 43  ['\n                    Банк вправе в одностор...
# 44  ['«Клиент имеет право досрочно погасить Задолж...
# 45  ['«В случае неоплаты платежа Клиент должен упл...
# 46  ['«На основании обращения Клиента и по согласо...
# 47  ['«3.2. По заявлению Клиента, переданному в Ба...
# 48  ['«6.1. При обнаружении утери, кражи или порчи...
# 49  ['«6.1. [...] а также в случае изъятия Кредитн...
# 50  ['«5.15. На основании обращения Клиента и по с...
# 51  ['Банк имеет установленные процедуры для обраб...
# 52  ['В случае смерти клиента банк замораживает де...
# 53  ['Клиенты имеют право отказаться от получения ...
# 54  ['Для увеличения кредитного лимита клиенты дол...
# 55  ['Клиенты могут отменить определенные банковск...
# 56  ['Через Интернет-банк клиенты могут управлять ...
# 57  ['"8. Расторжение Договора кредитной карты\n  ...
#
#                                          ground_truth  \
# 0   При отсутствии подписи карта может быть не при...
# 1   Не передавайте карту другим лицам, в т.ч. родс...
# 2   Да, однако не указывайте в названии заметки, ч...
# 3   Если вы не уверены, что карту украли, не спеши...
# 4   Важно проверять правильность суммы перед подпи...
# 5   Если вы потеряли телефон с установленным мобил...
# 6   Нет, не рекомендуется использовать интернет-ка...
# 7   Если вы получили SMS-оповещение о операции, ко...
# 8   Чтобы обезопасить себя от съема данных карты в...
# 9   Нет, неправда. При бронировании гостиницы по к...
# 10  \n                        Если вы из другой ст...
# 11  Выписка из Единого государственного реестра юр...
# 12  Да, индивидуальному предпринимателю необходимо...
# 13  Да, Банк может запросить у Вас дополнительные ...
# 14  Физическому лицу для открытия счета необходимо...
# 15  Юридическому лицу необходимо предоставить учре...
# 16  Да, индивидуальному предпринимателю-иностранно...
# 17  Для открытия счета нотариусу, занимающемуся ча...
# 18  Для идентификации бенефициарного владельца юри...
# 19   Да, конечно! Договор страхования — это догово...
# 20   \n                    Минимальная страховая в...
# 21  \n                    Согласно пункту 5.1 поль...
# 22  Страховщик ведет аудио, видеозапись, фотографи...
# 23  По договорам добровольного страхования непредв...
# 24  При возникновении вопросов или спора с АО 'Тин...
# 25  Дополнительная информация и документы о деятел...
# 26  Давайте разберемся! \n                    Парт...
# 27  Да, Вас действительно должнен сфотографировать...
# 28  \n                    В соответсвии с пунктом ...
# 29  Сертификат качества слитка - это документ, выд...
# 30  Доверенность выдается сроком на 1 год. Полномо...
# 31  По требованию клиента банк предоставляет ему з...
# 32  Слитки хранятся в специальном хранилище 5 клас...
# 33  Да, если при получении слитка с хранения были ...
# 34  Доверенным лицом клиента может стать любое физ...
# 35  Да, клиент может отменить ранее выданную довер...
# 36  Банк осуществляет покупку слитков драгоценных ...
# 37  \n                    Накопительный счет - это...
# 38  Нет, Банк не заключает договор вклада с лицами...
# 39   \n                    Да, вы можете открыть н...
# 40  Да, в таком случае необходимы справки из психо...
# 41  Да, в соответсвии с пунктом 3.1. Банк предоста...
# 42  Нет, страховое покрытие не распространяется на...
# 43  Да, Банк может изменить Тарифный план по креди...
# 44  Да, Клиент имеет право совершить частичное дос...
# 45  В случае неоплаты минимального платежа по кред...
# 46  Да, на основании обращения Клиента и по соглас...
# 47  Вы можете оформить дополнительную кредитную ка...
# 48  В случае утери или кражи кредитной карты, вы д...
# 49  Если вы забыли карту в банкомате, вам необходи...
# 50  Да, в документе указано, что по обращению клие...
# 51  Банк следует четко установленным процедурам дл...
# 52  После смерти клиента банк замораживает все его...
# 53  Клиенты могут отказаться от получения определе...
# 54  Чтобы увеличить кредитный лимит, клиентам необ...
# 55  Условия отмены банковской операции зависят от ...
# 56  Интернет-банк предоставляет клиентам возможнос...
# 57  Согласно пунуту 8.6 - вы не можете вернуть ваш...
#
#                                                answer
# 0   Нет, согласно пользовательскому соглашению бан...
# 1   Нет, это может быть опасно, так как ваша карта...
# 2   Нет, не безопасно. Хранение ПИН-кода в заметка...
# 3   Если Вы потеряли карту, Вам следует немедленно...
# 4   Подпись на квитанции или чеке является подтвер...
# 5   Если вы потеряли телефон, на котором было уста...
# 6   Нет, не рекомендуется использовать интернет-ка...
# 7   Если вы получили SMS-оповещение о операции по ...
# 8   Чтобы обезопасить себя от съема данных карты в...
# 9   Нет, при бронировании гостиницы по карте вам н...
# 10  Для того чтобы стать клиентом банка Tinkoff, в...
# 11  Выписка из ЕГРЮЛ действительна в течение 30 ка...
# 12  Нет, ИП не обязан указывать свой сайт для пред...
# 13  Да, Банк может запросить у клиента дополнитель...
# 14  Для открытия счета физическому лицу необходимо...
# 15  Для открытия счета в Банке юридическому лицу н...
# 16  Да, индивидуальный предприниматель – иностранн...
# 17  Для открытия счета для нотариуса, занимающегос...
# 18  Для того чтобы узнать, кто является бенефициар...
# 19  Договор страхования - это соглашение между стр...
# 20  Извините, но я не могу предоставить конкретную...
# 21  Ваши данные могут быть получены третьими лицам...
# 22  Страховщик может вести аудио- и видеозапись пр...
# 23  Планируемые расходы по страховому случаю могут...
# 24  Пользователь может направить обращение в служб...
# 25  Дополнительную информацию и документы о деятел...
# 26  Партия - это определенное количество драгоценн...
# 27  Да, согласно пункту 2.13.12 Пользовательского ...
# 28  Условия хранения включают температуру воздуха ...
# 29  Сертификат качества слитка - это документ, кот...
# 30  Эта доверенность выдана сроком на 1 (один) год...
# 31  Клиент может запросить заверенную банком копию...
# 32  Слитки в банке Tinkoff хранятся в специальном ...
# 33  Да, согласно пользовательскому соглашению банк...
# 34  Доверенным лицом может стать любое физическое ...
# 35  Да, клиент может изменить доверенное лицо. Для...
# 36  Покупка слитка банком Tinkoff происходит следу...
# 37  Накопительный счет - это счет, на котором учит...
# 38  Да, согласно условиям открытия вкладов в банке...
# 39  Да, вы можете открыть несколько вкладов и попо...
# 40  Нет, справка из психбольницы не требуется для ...
# 41  Да, банк Tinkoff предоставляет кредит на приоб...
# 42  Нет, страховое покрытие не распространяется на...
# 43  Да, банк Tinkoff имеет право изменить Тарифный...
# 44  Да, в банке Tinkoff возможно внесение частично...
# 45  В случае просрочки платежа по кредиту могут бы...
# 46  Да, согласно условиям договора кредитной карты...
# 47  Чтобы оформить дополнительную карту на супругу...
# 48  Если вы потеряли карту или ее украли, вам след...
# 49  Если вы забыли забрать карту из банкомата, вам...
# 50  Да, согласно условиям пользовательского соглаш...
# 51  Процедуры, предусмотренные банком для обработк...
# 52  В случае смерти клиента, его депозиты переходя...
# 53  Да, вы можете отказаться от получения уведомле...
# 54  Для увеличения лимита по своей кредитной карте...
# 55  Для отмены банковской операции, такой как пере...
# 56  Через Интернет-банк клиенты могут осуществлять...
# 57  Да, вы можете вернуть свои деньги, которые ост...

# %%
df.to_csv('../rag_answer/rag_step_query_translation/rag_step_back.csv', index=False)
