# %% [markdown]
# ## Variant 2 co.rerank
#
# `co.rerank` используется для повторного ранжирования списка документов на основе их релевантности к запросу. Этот метод обычно применяется после первоначального поиска, чтобы улучшить порядок документов по их значимости.
#
# ### Пример работы co.rerank:
#
# 1. **Поиск документов**: Сначала документы ищутся с помощью `retriever`.
# 2. **Повторное ранжирование**: `co.rerank` применяется к найденным документам для их повторного упорядочивания на основе релевантности к запросу.
# 3. **Возвращение документов**: Возвращаются документы в новом порядке, основанном на результатах повторного ранжирования.

# %% [markdown]
# ### Библиотеки

# %% [markdown]
# ![structure.png](../Schemes/Retrieval_rerank.png)

# %%
from necessity import *

# LangSmith
os.environ["LANGCHAIN_PROJECT"] = "Retrieval_ReRank"

# %%
# OpenAI proxy
llm=ChatOpenAI(model_name="gpt-3.5-turbo-0125")
embeddings_model = OpenAIEmbeddings()

# %%
# получаем смысловую разбивку всех документов
# splits = split_documents_my_html()
splits = split_documents_html(chunk_size=1000, chunk_overlap=100)
# splits = split_documents_standart(chunk_size=1000, chunk_overlap=100)

# индексируем
# embeddings_model = GigaChatEmbeddings(scope="GIGACHAT_API_PERS", verify_ssl_certs=False)
vectorstore = Chroma.from_documents(documents=splits, embedding=embeddings_model)

# %%
# # подключаем llm
# llm = GigaChat(model='GigaChat-Plus', verify_ssl_certs=False, scope="GIGACHAT_API_PERS")

# %%
# получаем только уникальные документы из всего списка
def get_unique_documents(documents):
    unique_documents = []
    seen_contents = set()

    for doc in documents:
        content = doc.page_content
        if content not in seen_contents:
            unique_documents.append(doc)
            seen_contents.add(content)

    return unique_documents

# по списку документов получаем определенный с page_content=target_page_content
def get_document_by_content(documents, target_page_content):
    for doc in documents:
        if doc.page_content == target_page_content:
            return doc
        

# Определяем функцию rerank_doc
def rerank_doc(query: str, top_n: int):
    retrieved_docs = retriever.invoke(query)
    unique_docs = get_unique_documents(retrieved_docs)
    
    # Rerank documents
    rerank_results = co.rerank(
        query=query, 
        documents=[doc.page_content for doc in unique_docs], 
        top_n=top_n, 
        model="rerank-multilingual-v3.0",
        return_documents=True
    )
    
    reranked_docs = []
    
    for info in rerank_results.results:
        doc = get_document_by_content(unique_docs, info.document.text)
        doc.metadata['relevance_score'] = info.relevance_score
        reranked_docs.append(doc)
        
    return reranked_docs

# Определяем функцию для ранжирования документов
def rerank_retriever(query):
    return rerank_doc(query, top_n=4)

retriever = vectorstore.as_retriever(
    search_type="similarity",
    search_kwargs={'k': 25}
)

# Определяем шаблон для запроса
prompt = ChatPromptTemplate.from_template("""
        Вы являетесь экспертом в области знаний пользовательских соглашений для банка Tinkoff и помогаете отвечать на вопросы.\n
        Я собираюсь задать вам вопрос. Ваш ответ должен быть исчерпывающим и основываться на следующем контексте (контекст хранится в Context), если он уместен. \n
        Отвечайте от лица представителя Банка и не уходите от темы, ответ должен быть не коротким, а полным.
        
        Question: {question} 
        Context: {context} 
        Answer:""")


# Создаем новую RAG цепочку с использованием rerank_retriever
rag_chain_rerank = (
    {"context": rerank_retriever, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)

# Пример использования новой цепочки
response = rag_chain_rerank.invoke("Какие документы потребуются, если открывать счет для нотариуса, занимающегося частной практикой? Может ли нотариус быть иностранцем при этом?")
# response = rag_chain_rerank.invoke("Какой минимум страховой выплаты мне вернут, если моя страховая сумма = 50 000 долларов?")
print(response)
# Out:
# Для открытия счета нотариусу, занимающемуся частной практикой, потребуется предоставление следующих документов:
#
# 1. Документ, удостоверяющий личность нотариуса.
# 2. Документ, подтверждающий регистрацию нотариуса в реестре адвокатов.
# 3. Документ, подтверждающий учреждение адвокатского кабинета нотариусом.
# 4. Адрес места жительства или пребывания нотариуса.
# 5. Контактная информация нотариуса, такие как номер телефона, адрес электронной почты и т.д.
# 6. Сведения об идентификационном номере налогоплательщика.
# 7. Информация о страховом номере индивидуального лицевого счета застрахованного лица, если необходимо.
# 8. Сведения о целях установления и предполагаемом характере деловых отношений с Банком.
#
# Относительно вопроса о том, может ли нотариус быть иностранцем при открытии счета, следует обратить внимание на требования законодательства Российской Федерации. В соответствии с законодательством, иностранный нотариус может быть допущен к частной практике в России при соблюдении определенных условий и получении соответствующих разрешений. Поэтому, если иностранный нотариус имеет все необходимые документы и разрешения для работы в России, то он может открыть счет в банке Tinkoff для своей частной практики. Важно также учитывать, что банк может потребовать дополнительные документы или информацию в зависимости от конкретной ситуации и требований законодательства.

# %%
response = rag_chain_rerank.invoke("Какие документы потребуются, если открывать счет для нотариуса, занимающегося частной практикой? Может ли нотариус быть иностранцем при этом?")
response
# Out:
# 'Для открытия счета для нотариуса, занимающегося частной практикой, потребуются следующие документы:\n\n1. Документ, удостоверяющий личность (паспорт или иной документ, указанный в перечне);\n2. Документ, удостоверяющий регистрацию физического лица в реестре адвокатов;\n3. Документ, подтверждающий учреждение физическим лицом адвокатского кабинета;\n4. Адрес места жительства (регистрации) или места пребывания;\n5. Контактная информация (номер телефона, адрес электронной почты и т.д.);\n6. Сведения об идентификационном номере налогоплательщика;\n7. Информация о страховом номере индивидуального лицевого счета застрахованного лица;\n8. Сведения о целях установления и предполагаемом характере деловых отношений с Банком.\n\nКроме того, необходимо предоставить выписку из ЕГРИП. Эта выписка должна быть актуальной на момент предоставления и содержать информацию о регистрации нотариуса.\n\nОтносительно иностранного нотариуса, важно отметить, что он также может открыть счет в Банке Tinkoff, если предоставит необходимые документы и сведения, указанные в перечне. В частности, иностранный нотариус должен предоставить документ, подтверждающий его право на пребывание (проживание) в Российской Федерации, если такое требование предусмотрено законодательством.\n\nТаким образом, открытие счета для нотариуса, занимающегося частной практикой, доступно как для граждан России, так и для иностранных граждан, при условии предоставления всех необходимых документов и сведений согласно требованиям Банка и законодательства РФ.'

# %%
def compare(query: str, top_n: int):
    retrieved_docs = retriever.invoke(query)
    
    print(f"Unique documents count: {len(retrieved_docs)}")
    
    print('Query:', query)
    # добавляем индексацию в метадату
    for idx, doc in enumerate(retrieved_docs):
        doc.metadata["initial_position"] = idx

    # Create a mapping from document content to its position
    content_to_initial_position = {doc.page_content: doc.metadata["initial_position"] for doc in retrieved_docs}
    
    # Rerank documents
    rerank_results = co.rerank(
        query=query, 
        documents=[doc.page_content for doc in retrieved_docs], 
        top_n=top_n, 
        model="rerank-multilingual-v3.0",
        return_documents=True
    )
    
    # Compare order change
    original_docs = []
    reranked_docs = []
    
    for new_position, info in enumerate(rerank_results.results):
        original_position = content_to_initial_position[info.document.text]
        print(f"{original_position} -> {new_position}")
        if new_position != original_position:
            original_docs.append([original_position, info.document.text])
            reranked_docs.append([new_position, retrieved_docs[new_position].page_content])
        

    for orig, rerank in zip(original_docs, reranked_docs):
        print(f"ORIGINAL {orig[0]}\n{orig[1]}\nRERANKED {rerank[0]}\n{rerank[1]}\n---------------")
        
    return rerank_results


# answer_1 = rag_chain.invoke("При принятии пользовательских соглашений, кому еще попадают мои данные?")
# answer_2 = rag_chain.invoke("Я не пользовалась кредиткой год, но у меня там лежат мои 800 рублей, я могу их как-то вернуть?")
# answer_3 = rag_chain.invoke("Какие документы потребуются, если открывать счет для нотариуса, занимающегося частной практикой? Может ли нотариус быть иностранцем при этом?")
# answer_4 = rag_chain.invoke("Какой минимум страховой выплаты мне вернут, если моя страховая сумма = 50 000 долларов?")

a = compare("На какой срок выдается эта доверенность? Можно ли ее передоверить другому лицу?", 25)
a
# Out:
# Unique documents count: 25
# Query: На какой срок выдается эта доверенность? Можно ли ее передоверить другому лицу?
# 0 -> 0
# 10 -> 1
# 12 -> 2
# 24 -> 3
# 20 -> 4
# 18 -> 5
# 6 -> 6
# 5 -> 7
# 13 -> 8
# 7 -> 9
# 19 -> 10
# 3 -> 11
# 11 -> 12
# 22 -> 13
# 9 -> 14
# 4 -> 15
# 23 -> 16
# 16 -> 17
# 21 -> 18
# 1 -> 19
# 2 -> 20
# 17 -> 21
# 8 -> 22
# 14 -> 23
# 15 -> 24
# ORIGINAL 10
# средством, или собственнику транспортного средства, в соответствии со статьей 313 Гражданского кодекса Российской Федерации, оплата страховой премии может быть произведена указанными лицами. Лицо, допущенное к управлению транспортным средством, или собственник транспортного средства уведомляют Страхователя о заключении договора ОСАГО и (или) договора КАСКО по его поручению не позднее 2 (двух) дней после заключения договора. Принятием страхового полиса Страхователь подтверждает его уведомление указанными лицами о заключении договора по его поручению и наличие полномочий у таких лиц на заключение от его имени договора ОСАГО и (или) договора КАСКО. 2.18. Если это прямо предусмотрено договором страхования, его действие может быть автоматически продлено на новый срок, при соблюдении условий такого продления, предусмотренных договором страхования. В любом случае договор страхования продлевается на каждый последующий срок на тех же условиях с даты, следующей за датой окончания срока
# RERANKED 1
# 5.1. Предусмотренный настоящими Правилами Сервис оказывается Клиенту Банком, в том числе привлеченными им лицами.5.2. Подтверждением получения Банком / Клиентом/ Доверенным лицом слитка в ненарушенной упаковке является видеозапись, указанная в п. 2.13.1. а также фотоизображение Клиента/ Доверенного лица со Слитком, указанное в п.2.13.12. настоящих Правил. Данная видеозапись и фотоизображение могут использоваться в качестве доказательства при наличии у Клиента претензий, в том числе в су
САГО и (или) договора КАСКО по его поручению не позднее 2 (двух) дней после заключения договора. Принятием страхового полиса Страхователь подтверждает его уведомление указанными лицами о заключении договора по его поручению и наличие полномочий у таких лиц на заключение от его имени договора ОСАГО и (или) договора КАСКО. 2.18. Если это прямо предусмотрено договором страхования, его действие может быть автоматически продлено на новый срок, при соблюдении условий такого продления, предусмотренных договором страхования. В любом случае договор страхования продлевается на каждый последующий срок на тех же условиях с даты, следующей за датой окончания срока'), index=10, relevance_score=0.043204036), RerankResponseResultsItem(document=RerankResponseResultsItemDocument(text='денежных средств в течение 120 (ста двадцати) дней со дня обработки Банком последней операции Клиента/Держателя и, если остаток денежных средств не превышает 1000 руб., указанный остаток считается безвозмездно переданным Банку. В случае неполучения Банком распоряжения Клиента о переводе денежных средств в течение 3 (трех) лет со дня обработки Банком последней операции Клиента/Держателя указанные денежные средства считаются безвозмездно переданными Банку. 36 из 74'), index=12, relevance_score=0.03567855), RerankResponseResultsItem(document=RerankResponseResultsItemDocument(text='организации или индивидуального предпринимателя (продавца) в момент совершения Клиентом расчета с использованием Карты в рамках предоставления сервисов Банка и участия Клиента в маркетинговых мероприятиях и Программах лояльности, утвержденных Банком и/или партнерами Банка.3.4.15. Взыскивать Задолженность, возникшую из договоров, по которым Клиенту был предоставлен Кредит, по исполнительной надписи нотариуса.3.4.16. В случае, если при поступлении в Банк денежных средств, предназначенных Клиенту, у Банка возникают сомнения в источнике их происхождения и/или правовом основании для их перечисления Клиенту, Банк осуществляет зачисление этих денежных средств на отдельный счет, на срок, не превышающий 5 (пяти) рабочих дней, в течение которых Клиент обязуется по запросу Банка предоставить в Банк сведения и документы, подтверждающие источник происхождения денежных средств и основания для их зачисления. Если в установленный срок Клиент не предоставит в Банк запрошенные сведения и документы или'), index=24, relevance_score=0.027742893), RerankResponseResultsItem(document=RerankResponseResultsItemDocument(text='регистрирующим органом. Выписка считается действительной для предоставления в Банк в течение 30 (тридцати) календарных дней с даты ее выдачи и должна содержать актуальные сведения на дату ее предоставления;15.5. Контактная информация (например, номер телефона, факса, адрес электронной почты, почтовый адрес (при наличии);15.6. Адрес места жительства (регистрации) или места пребывания (если его нельзя установить из документа, удостоверяющего личность, а также если адрес места жительства  ...

# %%
response = rag_chain_rerank.invoke("Какие документы потребуются, если открывать счет для нотариуса, занимающегося частной практикой? Может ли нотариус быть иностранцем при этом?")
# response = rag_chain_rerank.invoke("Какой минимум страховой выплаты мне вернут, если моя страховая сумма = 50 000 долларов?")
print(response)
# Out:
# Для открытия счета нотариуса, занимающегося частной практикой, необходимо предоставить следующие документы:
#
# 1. Документ, удостоверяющий личность и указанный в пункте 1.4 настоящего Перечня.
# 2. Документ, подтверждающий наделение нотариуса полномочиями (назначение на должность), выдаваемый органами юстиции субъектов Российской Федерации, в соответствии с законодательством Российской Федерации.
# 3. Адрес места жительства (регистрации) или места пребывания (если его нельзя установить из документа, удостоверяющего личность, а также если адрес места жительства (регистрации) или места пребывания не совпадают).
# 4. Контактная информация (например, номер телефона, факса, адрес электронной почты, почтовый адрес (при наличии).
# 5. Выписка из ЕГРИП. Банком может быть принята копия выписки, заверенная регистрирующим органом. Выписка считается действительной для предоставления в Банк в течение 30 (тридцати) календарных дней с даты ее выдачи и должна содержать актуальные сведения на дату ее предоставления.
#
# Ответ на второй вопрос: Да, нотариус может быть иностранцем при открытии счета в банке Tinkoff. Однако, для этого ему необходимо предоставить дополнительные документы, подтверждающие его статус и право на осуществление деятельности в России.

# %% [markdown]
# ### Вывод как меняются индексы

# %%
# retriever = vectorstore.as_retriever(
#     search_type="similarity",
#     search_kwargs={'k': 25}
# )

# def compare(query: str, top_n: int):
#     retrieved_docs = retriever.invoke(query)
    
#     print(f"Unique documents count: {len(retrieved_docs)}")
    
#     print('Query:', query)
#     # добавляем индексацию в метадату
#     for idx, doc in enumerate(retrieved_docs):
#         doc.metadata["initial_position"] = idx

#     # Create a mapping from document content to its position
#     content_to_initial_position = {doc.page_content: doc.metadata["initial_position"] for doc in retrieved_docs}
    
#     # Rerank documents
#     rerank_results = co.rerank(
#         query=query, 
#         documents=[doc.page_content for doc in retrieved_docs], 
#         top_n=top_n, 
#         model="rerank-multilingual-v3.0",
#         return_documents=True
#     )
    
#     # Compare order change
#     original_docs = []
#     reranked_docs = []
    
#     for new_position, info in enumerate(rerank_results.results):
#         original_position = content_to_initial_position[info.document.text]
#         print(f"{original_position} -> {new_position}")
#         if new_position != original_position:
#             original_docs.append([original_position, info.document.text])
#             reranked_docs.append([new_position, retrieved_docs[new_position].page_content])
        

#     for orig, rerank in zip(original_docs, reranked_docs):
#         print(f"ORIGINAL {orig[0]}\n{orig[1]}\nRERANKED {rerank[0]}\n{rerank[1]}\n---------------")
        
#     return rerank_results

# a = compare("Какой минимум страховой выплаты мне вернут, если моя страховая сумма = 50 000 долларов?", 25)
# a

# %% [markdown]
# ### Загрузка Датасета

# %% [markdown]
# Giga generation stopped with reason: blacklist
# ReadTimeout: The read operation timed out

# %%
import pandas as pd
import time

# Загрузка данных
df = pd.read_csv('../dataset.csv')

# Функция для обработки одного запроса с учетом задержки и повторных попыток
def process_question(question):
    max_retries = 3
    delay = 3  # задержка между попытками в секундах
    
    for attempt in range(max_retries):
        try:
            answer = rag_chain_rerank.invoke(question.strip())
            return answer
        except Exception as e:
            print(f"Attempt {attempt + 1} failed with error: {e}")
            if attempt < max_retries - 1:
                time.sleep(delay)  # Ждать перед следующей попыткой
            else:
                return "Error: Request timed out"

# Применение функции к каждому вопросу с задержкой между запросами
df['answer'] = df['question'].apply(lambda x: process_question(x.strip()))
# Out:
# Giga generation stopped with reason: blacklist
# Attempt 1 failed with error: The read operation timed out
# Attempt 2 failed with error: The read operation timed out
# Attempt 3 failed with error: The read operation timed out
# Giga generation stopped with reason: blacklist
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: [SSL: WRONG_VERSION_NUMBER] wrong version number (_ssl.c:2548)
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 2 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 2 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 2 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 1 failed with error: The read operation timed out
# Attempt 2 failed with error: Server disconnected without sending a response.

# %%
df
# Out:
#                                              question  \
# 0                 Можно ли не расписываться на карте?
# 1   Мой друг попросил меня дать свою карту для опл...
# 2   Безопасно ли хранить пинкод в заметках в телеф...
# 3                                    Я потеряла карту
# 4   Почему при использовании карты важно не распис...
# 5   Что делать, если я потеряла телефон, на которо...
# 6   Можно ли использовать интернет-кафе и другие о...
# 7   Что делать, если я получил SMS-оповещение о оп...
# 8   Как обезопасить себя от съема данных карты в б...
# 9   Правда ли, что при бронировании гостиницы по к...
# 10  Если я из другой страны и у меня нет паспорта ...
# 11  В течении скольких дней действительна выписка ...
# 12   Нужно ли ИП указывать свой сайт для предприятия?
# 13  Может ли Банк запросить дополнительные докумен...
# 14  Какие документы нужно предоставить физическому...
# 15  Какие документы необходимо предоставить юридич...
# 16  Можно ли открыть счет индивидуальному предприн...
# 17  Какие документы потребуются, если открывать сч...
# 18  Как узнать, кто является бенефициарным владель...
# 19  Расскажи про термины 'Договор страхования' и '...
# 20  Какой минимум страховой выплаты мне вернут, ес...
# 21  При принятии пользовательских соглашений, кому...
# 22  Зачем страховщик ведет аудио и видеозапись при...
# 23  В каких случаях застрахованному могут быть опл...
# 24  Куда пользователь может направить обращение пр...
# 25  Где можно ознакомиться с дополнительной информ...
# 26  Что означает 'Партия' и вообще 'Слиток' для др...
# 27  Меня действительно должны фотографировать посл...
# 28                            Какие условия хранения?
# 29            Что такое 'Сертификат качества слитка'?
# 30  На какой срок выдается эта доверенность? Можно...
# 31  Как клиент может получить сертификат качества ...
# 32  Какие условия хранения слитков в банке? Где их...
# 33  Можно ли вернуть слиток в банк, если при получ...
# 34                  Кто может стать доверенным лицом?
# 35  Можно ли поменять доверенное лицо? Как это сде...
# 36  Как происходит покупка слитка банком? Есть ли ...
# 37  Что такое накопительный счет и как начисляются...
# 38                   Можно ли открыть вклад в 12 лет?
# 39  Могу ли я открыть несколько вкладов и пополнят...
# 40  Для получения страховой выплаты в случае несча...
# 41                      Дают ли кредит на автомобиль?
# 42  Распростроняется ли страховое покрытие на смер...
# 43  Может ли Банк изменить Тарифный план по кредит...
# 44  Можно ли внести частичное досрочное погашение ...
# 45  Что будет в случае просрочки платежа по кредит...
# 46  Можно ли на время приостановить выплаты по кре...
# 47  Я хочу оформить дополнительную карту на супруг...
# 48  А что если я потеряю карту? Сколько у меня ест...
# 49  Прочитал тут у вас про блокировку карточки. А ...
# 50  А есть ли какие-то льготные условия, если я за...
# 51  Какие процедуры предусмотрены банком для обраб...
# 52       Что происходит с депозитами в случае смерти?
# 53  Могу я отказаться от получения уведомлений от ...
# 54  Как я могу увеличить лимит по своей кредитной ...
# 55  Каковы условия отмены банковской операции, нап...
# 56  Какие услуги доступны клиентам через Интернет-...
# 57  Я не пользовалась кредиткой год, но у меня там...
#
#                                              contexts  \
# 0   ['После получения карты поставьте свою подпись...
# 1   ['Никогда не принимайте рекомендации, советы, ...
# 2   ['Категорически запрещается записывать ПИН-код...
# 3   [' Вы потеряли карту или ее украли\nПрежде все...
# 4   ['Проверяйте правильность суммы, указанной на ...
# 5   ['При утрате Мобильного телефона, используемог...
# 6   ['Избегайте осуществления Интернет-операций с ...
# 7   ['Если Вы уверены, что операция не могла быть ...
# 8   ['Поэтому, при пользовании банкоматом не ленит...
# 9   ['При бронировании номера в гостинице по карте...
# 10  ['\n                     1. Документы и сведен...
# 11  ['\n                    2.2. Выписка из Единог...
# 12  ['\n                    3. Документы и сведени...
# 13  ['\n                     26. Банк может запрос...
# 14  ['1. Документы и сведения, получаемые в целях ...
# 15  ['2.1. Учредительные документы юридического ли...
# 16  ['3.1. Идентификация индивидуального предприни...
# 17  ['5.1. Документ, удостоверяющий личность и ука...
# 18  ['12. Идентификация бенефициарного(ых) владель...
# 19  ['1. Термины и определения     \n             ...
# 20   \n                    2.19.   При добровольно...
# 21  ['\n                    5. Персональные данные...
# 22  ['При заключении Договоров страхования, а такж...
# 23  ['По договорам добровольного страхования непре...
# 24  ['При возникновении вопросов или спора можно о...
# 25  ['Дополнительная информация и документы о деят...
# 26  ['\n                    Партия — приобретенные...
# 27  ['\n                    2.13.12. После подтвер...
# 28  [' \n                    2.14.9. Условия хране...
# 29  ['Сертификат качества слитка — документ о каче...
# 30  ['Датой выдачи доверенности считается дата пре...
# 31  ['По требованию Клиента Банк предоставляет Кли...
# 32  ['Хранение Банком Слитка Клиента осуществляетс...
# 33  ['В случае обнаружения при приеме Слитка с отв...
# 34  ['Доверенное лицо — физическое лицо, уполномоч...
# 35  ['Клиент может отменить выданную доверенность ...
# 36  ['Банк приобретает у Клиента только Слитки, на...
# 37  ['\n                    3.1. Начисление процен...
# 38  ['1.2. Банк не заключает Договор вклада (Догов...
# 39  ['\n                    4.1. Клиент имеет прав...
# 40  ['\n                    6.1. По риску Смерть в...
# 41  ['3.1. Банк предоставляет Клиенту Кредит на по...
# 42  [' \n                    Страховое покрытие по...
# 43  ['\n                    Банк вправе в одностор...
# 44  ['«Клиент имеет право досрочно погасить Задолж...
# 45  ['«В случае неоплаты платежа Клиент должен упл...
# 46  ['«На основании обращения Клиента и по согласо...
# 47  ['«3.2. По заявлению Клиента, переданному в Ба...
# 48  ['«6.1. При обнаружении утери, кражи или порчи...
# 49  ['«6.1. [...] а также в случае изъятия Кредитн...
# 50  ['«5.15. На основании обращения Клиента и по с...
# 51  ['Банк имеет установленные процедуры для обраб...
# 52  ['В случае смерти клиента банк замораживает де...
# 53  ['Клиенты имеют право отказаться от получения ...
# 54  ['Для увеличения кредитного лимита клиенты дол...
# 55  ['Клиенты могут отменить определенные банковск...
# 56  ['Через Интернет-банк клиенты могут управлять ...
# 57  ['"8. Расторжение Договора кредитной карты\n  ...
#
#                                          ground_truth  \
# 0   При отсутствии подписи карта может быть не при...
# 1   Не передавайте карту другим лицам, в т.ч. родс...
# 2   Да, однако не указывайте в названии заметки, ч...
# 3   Если вы не уверены, что карту украли, не спеши...
# 4   Важно проверять правильность суммы перед подпи...
# 5   Если вы потеряли телефон с установленным мобил...
# 6   Нет, не рекомендуется использовать интернет-ка...
# 7   Если вы получили SMS-оповещение о операции, ко...
# 8   Чтобы обезопасить себя от съема данных карты в...
# 9   Нет, неправда. При бронировании гостиницы по к...
# 10  \n                        Если вы из другой ст...
# 11  Выписка из Единого государственного реестра юр...
# 12  Да, индивидуальному предпринимателю необходимо...
# 13  Да, Банк может запросить у Вас дополнительные ...
# 14  Физическому лицу для открытия счета необходимо...
# 15  Юридическому лицу необходимо предоставить учре...
# 16  Да, индивидуальному предпринимателю-иностранно...
# 17  Для открытия счета нотариусу, занимающемуся ча...
# 18  Для идентификации бенефициарного владельца юри...
# 19   Да, конечно! Договор страхования — это догово...
# 20   \n                    Минимальная страховая в...
# 21  \n                    Согласно пункту 5.1 поль...
# 22  Страховщик ведет аудио, видеозапись, фотографи...
# 23  По договорам добровольного страхования непредв...
# 24  При возникновении вопросов или спора с АО 'Тин...
# 25  Дополнительная информация и документы о деятел...
# 26  Давайте разберемся! \n                    Парт...
# 27  Да, Вас действительно должнен сфотографировать...
# 28  \n                    В соответсвии с пунктом ...
# 29  Сертификат качества слитка - это документ, выд...
# 30  Доверенность выдается сроком на 1 год. Полномо...
# 31  По требованию клиента банк предоставляет ему з...
# 32  Слитки хранятся в специальном хранилище 5 клас...
# 33  Да, если при получении слитка с хранения были ...
# 34  Доверенным лицом клиента может стать любое физ...
# 35  Да, клиент может отменить ранее выданную довер...
# 36  Банк осуществляет покупку слитков драгоценных ...
# 37  \n                    Накопительный счет - это...
# 38  Нет, Банк не заключает договор вклада с лицами...
# 39   \n                    Да, вы можете открыть н...
# 40  Да, в таком случае необходимы справки из психо...
# 41  Да, в соответсвии с пунктом 3.1. Банк предоста...
# 42  Нет, страховое покрытие не распространяется на...
# 43  Да, Банк может изменить Тарифный план по креди...
# 44  Да, Клиент имеет право совершить частичное дос...
# 45  В случае неоплаты минимального платежа по кред...
# 46  Да, на основании обращения Клиента и по соглас...
# 47  Вы можете оформить дополнительную кредитную ка...
# 48  В случае утери или кражи кредитной карты, вы д...
# 49  Если вы забыли карту в банкомате, вам необходи...
# 50  Да, в документе указано, что по обращению клие...
# 51  Банк следует четко установленным процедурам дл...
# 52  После смерти клиента банк замораживает все его...
# 53  Клиенты могут отказаться от получения определе...
# 54  Чтобы увеличить кредитный лимит, клиентам необ...
# 55  Условия отмены банковской операции зависят от ...
# 56  Интернет-банк предоставляет клиентам возможнос...
# 57  Согласно пунуту 8.6 - вы не можете вернуть ваш...
#
#                                                answer
# 0   Согласно условиям пользования картой Tinkoff, ...
# 1   Не люблю менять тему разговора, но вот сейчас ...
# 2   Хранение пин-кода в заметках в телефоне являет...
# 3                            Error: Request timed out
# 4   Как у нейросетевой языковой модели у меня не м...
# 5   Если вы потеряли телефон, на котором было уста...
# 6   Да, использование интернет-кафе и других общед...
# 7   Если вы получили SMS-оповещение о операции по ...
# 8   Для защиты от съема данных карты в банкомате з...
# 9   При бронировании гостиницы по карте Tinkoff, в...
# 10  Если вы являетесь иностранным гражданином и не...
# 11  Выписка из ЕГРЮЛ действительна в течение 30 ка...
# 12  В соответствии с требованиями Банка, индивидуа...
# 13  Да, Банк может запросить дополнительные докуме...
# 14  Для открытия счета в Банке Tinkoff физическому...
# 15  Для открытия счета в Банке юридическому лицу н...
# 16  Да, индивидуальный предприниматель – иностранн...
# 17  Для открытия счета нотариуса, занимающегося ча...
# 18  Для того чтобы узнать, кто является бенефициар...
# 19  Договор страхования - это договор, по которому...
# 20  В соответствии с условиями страхования по «Про...
# 21  Ваши данные могут быть переданы Страховым брок...
# 22  Страховщик ведет аудио и видеозапись при взаим...
# 23  Застрахованному могут быть оплачены планируемы...
# 24  Пользователь может направить обращение при воз...
# 25  Дополнительная информация и документы о деятел...
# 26  Термин "Партия" в контексте оказания сервиса "...
# 27  Согласно пункту 2.13.12 Правил оказания сервис...
# 28  Слиток Банка Tinkoff хранится в хранилище 5 кл...
# 29  Сертификат качества слитка - это документ, кот...
# 30  Доверенность выдается сроком на 1 (один) год. ...
# 31  Для получения сертификата качества слитка, кот...
# 32  Слитки в банке Tinkoff хранятся в хранилище 5 ...
# 33  Да, вы можете вернуть слиток в банк, если при ...
# 34  Доверенным лицом может стать представитель Кли...
# 35  Да, клиент может поменять доверенное лицо. Для...
# 36  Процесс покупки слитка банком Tinkoff включает...
# 37  Накопительный счет - это счет, на котором учит...
# 38  Согласно условиям, установленным Банком Tinkof...
# 39  Да, согласно условиям договора вклада в Банке ...
# 40  Для получения страховой выплаты в случае смерт...
# 41  Да, Банк Tinkoff предоставляет кредит на автом...
# 42  Страховое покрытие по рискам «Смерть» и «Инвал...
# 43  Да, Банк имеет право изменить Тарифный план по...
# 44  Да, в Банке Tinkoff возможно частичное досрочн...
# 45  В случае просрочки платежа по кредиту в банке ...
# 46  Да, на основании обращения клиента и по соглас...
# 47  Для оформления дополнительной карты на супругу...
# 48  Если вы обнаружите, что ваша карта была утерян...
# 49  Если Вы забыли забрать свою карту из банкомата...
# 50  Да, в соответствии с условиями программы "Расс...
# 51  Банк Tinkoff имеет процедуры для обработки жал...
# 52  В случае смерти клиента, его депозиты в банке ...
# 53  Да, вы можете отказаться от получения уведомле...
# 54  Для увеличения лимита по кредитной карте в Бан...
# 55  Условия отмены банковской операции, такой как ...
# 56  Клиенты Банка Tinkoff могут воспользоваться ши...
# 57  Да, согласно условиям кредитной карты Tinkoff,...

# %%
display(df)

# %%
df.to_csv('../rag_answer/rag_step_retriever/html_split/rag_rerank_gigachat_plus.csv', index=False)

# %% [markdown]
# ### Сравнение двух подходов
#
# - **`compression_retriever.get_relevant_documents(query)`**: Этот метод не просто повторно ранжирует документы, а также извлекает и сжимает наиболее важные части каждого документа, предоставляя сжатую, но релевантную информацию.
# - **`co.rerank(query, documents)`**: Этот метод сохраняет оригинальные документы и только изменяет порядок их следования на основе их релевантности к запросу.
