# %% [markdown]
# ## Создание большого датасета на основе маленького
#
# (с применением сгенерированного датасета от Claude и ChatGpt4)

# %% [markdown]
# ### Структура
#
# *<b>question</b>:*
#
#         Можно ли не расписываться на карте?
#
# *<b>contexts</b>:*
#
#         После получения карты поставьте свою подпись в прямоугольнике, расположенном на оборотной стороне карты. При отсутствии подписи карта может быть не принята к оплате в торгово-сервисном предприятии, а также повышается риск использования карты злоумышленниками в случае ее утраты/кражи.
#
# *<b>ground_truth</b>:*
#
#         При отсутствии подписи карта может быть не принята к оплате в торгово-сервисном предприятии, а также повышается риск использования карты злоумышленниками в случае ее утраты/кражи.

# %%
data = []

# %% [markdown]
# ## Датасет по документам

# %% [markdown]
# #### 1_Безопасное использование банковской карты.pdf>

# %%
data.append(
    {
        "question": "Можно ли не расписываться на карте?",
        "contexts": ["После получения карты поставьте свою подпись в прямоугольнике, расположенном на оборотной стороне карты. При отсутствии подписи карта может быть не принята к оплате в торгово-сервисном предприятии, а также повышается риск использования карты злоумышленниками в случае ее утраты/кражи."],
        "ground_truth": "При отсутствии подписи карта может быть не принята к оплате в торгово-сервисном предприятии, а также повышается риск использования карты злоумышленниками в случае ее утраты/кражи."
    }
)

data.append(
    {
        "question": "Мой друг попросил меня дать свою карту для оплаты и потом вернуть, это не опасно?",
        "contexts": ["Никогда не принимайте рекомендации, советы, помощь от третьих лиц при пользовании картой, особенно при снятии наличных денежных средств в банкоматах. В случае возникновения затруднений при совершении операции обратитесь Банк посредством дистанционного обслуживания. Обращайте внимание на расположение банкоматов. Старайтесь не пользоваться банкоматами, расположенными в плохо освещенных и безлюдных местах",
                     "Не передавайте карту другим лицам, в т.ч. родственникам и знакомым для проведения транзакций. С целью исключения Ваших потерь от несанкционированного использования Вашей карты (копирования информации с Вашей карты для ее дальнейшего мошеннического использования): при совершении операции оплаты с использованием карты никогда не выпускайте Вашу карту из поля зрения и требуйте от обслуживающего Вас лица, чтобы все операции с использованием карты совершались в Вашем присутствии."],
        "ground_truth": "Не передавайте карту другим лицам, в т.ч. родственникам и знакомым для проведения транзакций и никогда не принимайте рекомендации, советы, помощь от третьих лиц при пользовании картой, особенно при снятии наличных денежных средств в банкоматах."
    }
)

data.append(
    {
        "question": "Можно ли передавать продавцу свою карту при оплате на кассе или это небезапасно?",
        "contexts": ["Допускается передать карту при совершении оплаты, если терминалы не поддерживают функцию бесконтактной оплаты, но операции с использованием карты должны быть совершены в Вашем присутствии.",
                     """
• Не забывайте забрать Вашу карту после проведения операции. Убедитесь, что возвращенная карта принадлежит Вам. 
Запрещается оставлять под любым предлогом карту в организациях торговли (услуг).
• Проверяйте правильность суммы, указанной на платежном чеке. Поставив подпись на платежном чеке, Вы 
соглашаетесь со списанием указанной на нем суммы с Вашего карточного счета.
• Не используйте карту для оплаты, если кассир или торговая точка не вызывают у Вас доверия. Особенно осторожно 
используйте карту в странах повышенного риска (Таиланд, Тайвань, Филиппины, Турция, Мексика, Венесуэла, 
Гонконг, Индонезия, Украина, США, Индия, Беларусь). В этих странах высок риск копирования данных Вашей карты 
и использования их для изготовления подделок. В таких странах для снятия наличных денежных средств рекомендуется 
использовать банкоматы известных банков, которые установлены в отделениях и крупных торговых центрах.
• Запомните, что по операциям оплаты товаров и услуг в торгово-сервисных предприятиях картой Тинькофф Банка 
введение ПИН-кода не требуется, если в Мобильном Банке Вы не выбрали опцию подтверждения покупок Пин-кодом.
Обязательно сохраняйте все документы по операциям до момента отражения в выписке по Вашей карте.
• Как можно чаще (минимально — при получении ежемесячной выписки) проверяйте выписку по Вашей карте 
и соответствие указанных в ней операций реально произведенным расходам. В случае обнаружения каких-либо 
расхождений, обратитесь в Банк посредством дистанционного обслуживания. Не сообщайте реквизиты Вашей 
банковской карты (номер карты, срок действия, трехзначный код безопасности, ПИН-код), за исключением 
использования Вами автоматизированных систем MOTO и систем интернет коммерции.
• Не сообщайте данные своего Заявления-Анкеты, направленного в Банк, и, особенно, кодовое слово, третьим лицам. 
Помните, Банк получил Ваши персональные данные вместе с Заявлением-Анкетой. Кодовое слово необходимо как 
дополнительный критерий для идентификации Вас в качестве клиента Банка (в т.ч. при обращении для разблокировки 
доступов и пр.). О любых попытках узнать Ваши персональные данные немедленно сообщайте в Банк посредством 
дистанционного обслуживания. 
• Не используйте карту, которую Вы заявили, как утерянную или украденную. Если после блокировки, Вы обнаружили 
карту, Вам следует обратиться в Банк посредством дистанционного обслуживания для получения дальнейших 
инструкций.
• Для контроля операций по Вашей карте в режиме реального времени и своевременного выявления 
несанкционированных операций рекомендуем Вам подключить услугу Оповещение об операциях.
• Установите лимиты на платежи и снятие наличных по карте. Если с картой что-то случится, преступники не заберут 
все деньги на счете. Лимиты на снятие наличных и на операции по карте можно установить самостоятельно в разделе 
«Баланс и лимиты» в личном кабинете или разделе «Лимиты» мобильного приложения.
• Запишите телефонные номера Банка и всегда имейте эту информацию при себе, хранящейся отдельно от карты. Она 
может понадобиться Вам для экстренной блокировки Вашей карты, если карта будет утеряна или украдена."""],
        "ground_truth": "Да, можно в некоторых случаях, например, допускается передать карту при совершении оплаты, если терминалы не поддерживают функцию бесконтактной оплаты, но операции с использованием карты должны быть совершены в Вашем присутствии. В конце не забывайте забрать Вашу карту и сверить итоговую сумму в чеке."
    }
)

data.append(
    {
        "question": "Безопасно ли хранить пинкод в заметках в телефоне?",
        "contexts": ["Категорически запрещается записывать ПИН-код на карте. Постарайтесь не записывать ПИН-код, запомните его. Если же Вы предпочитаете записать свой ПИН-код, никогда не указывайте, что это ПИН-код и не храните документ с записанным ПИН-кодом рядом с картой."],
        "ground_truth": "Да, однако не указывайте в названии заметки, что это ПИН-код от Вашей карты."
    }
)

data.append(
    {
        "question": "Я потеряла карту",
        "contexts": [""" Вы потеряли карту или ее украли
Прежде всего, как можно быстрее, сообщите о случившемся в Банк посредством дистанционного обслуживания 
и заблокируйте карту. Заблокировать карту можно по телефону, в интернет-банке или в мобильном приложении Банка. 
Чем раньше Вы это сделаете, тем меньше вероятность несанкционированного использования карты злоумышленниками. 
Разблокировать карту нельзя — можно только перевыпустить. Если вы не уверены, что карту украли, не спешите ее 
блокировать, установите лимит «0» на операции и запретите покупки через Интернет, если карта будет найдена лимиты 
можно изменить.
Напоминаем Вам, что в соответствии с Общими условиями выпуска и обслуживания кредитных карт и Общими 
условиями открытия, ведения и закрытия счетов физических лиц, а также выпуска и обслуживания расчетных карт Ваша 
ответственность за дальнейшее использование карты прекращается, после осуществления блокировки, если не станет 
известно, что незаконное использование карты имело место с Вашего согласия.
Если карта была у Вас украдена на территории РФ, после блокировки карты заявите о случившемся в полицию. При краже 
карты за границей, заявите в полицию или в консульский отдел посольства Российской Федерации в стране, на территории 
которой произошла кража. Пожалуйста, сохраняйте копию протокола (квитанцию о заявлении) для последующего 
предъявления в Банк."""],
        "ground_truth": "Если вы не уверены, что карту украли, не спешите ее блокировать, установите лимит «0» на операции и запретите покупки через Интернет, если карта будет найдена лимиты можно изменить. В случае, если вы полагаете, что Вашу карту всё-таки украли, то как можно быстрее, сообщите о случившемся в Банк посредством дистанционного обслуживания и заблокируйте карту. Это возможно сделать по телефону, в интернет-банке или в мобильном приложении Банка."
    }
)

data.append(
    {
        "question": "Сколько стоит аренда автомобиля?",
        "contexts": [],
        "ground_truth": "Информации по Вашему вопросу в документах не найдено."
    }
)


data.append(
    {
        "question": "Почему при использовании карты важно не расписываться на квитанциях/чеках до того, как вы проверите правильность указанной суммы?",
        "contexts": [
            "Проверяйте правильность суммы, указанной на платежном чеке. Поставив подпись на платежном чеке, Вы соглашаетесь со списанием указанной на нем суммы с Вашего карточного счета."
        ],
        "ground_truth": "Важно проверять правильность суммы перед подписанием квитанции/чека, потому что после подписи вы соглашаетесь с этой суммой, и она будет списана с вашего счета."
    }
)

data.append(
    {
        "question": "Что делать, если вы потеряли телефон, на котором было установлено мобильное приложение банка? Приведите все необходимые шаги.",
        "contexts": [
            "При утрате Мобильного телефона, используемого с абонентским номером подвижной радиотелефонной связи, на который установлено Мобильное приложение Банка, Вам следует срочно обратиться к своему оператору сотовой связи для блокировки SIM-карты и в Банк посредством дистанционного обслуживания для блокировки доступа в мобильное приложение Банка и удаления данных карты с Мобильного телефона."
        ],
        "ground_truth": "Если вы потеряли телефон с установленным мобильным приложением банка, необходимо:\n\nСрочно обратиться к оператору сотовой связи для блокировки SIM-карты.\nОбратиться в банк через дистанционное обслуживание для блокировки доступа в мобильное приложение и удаления данных карты с телефона."
    }
)

data.append(
    {
        "question": "Можно ли использовать интернет-кафе и другие общедоступные места для совершения операций по карте в интернете? Объясните причину.",
        "contexts": [
            "Избегайте осуществления Интернет-операций с использованием карты в местах, где услуги Интернет являются общедоступными, например, в Интернет-кафе."
        ],
        "ground_truth": "Нет, не рекомендуется использовать интернет-кафе и другие общедоступные места для совершения операций по карте в интернете. Причина в том, что такие общедоступные сети являются менее безопасными, и есть риск перехвата данных карты злоумышленниками."
    }
)

data.append(
    {
        "question": "Что делать, если вы получили SMS-оповещение о операции по карте, которую вы не совершали?",
        "contexts": [
            "Если Вы уверены, что операция не могла быть совершена Вами, то как можно быстрее сообщите об этом в Банк посредством дистанционного обслуживания и заблокируйте карту."
        ],
        "ground_truth": "Если вы получили SMS-оповещение о операции, которую не совершали, нужно как можно быстрее сообщить об этом в банк через дистанционное обслуживание и заблокировать карту."
    }
)

data.append(
    {
        "question": "Как обезопасить себя от съема данных карты в банкомате злоумышленниками? Приведите два способа.",
        "contexts": [
            "Поэтому, при пользовании банкоматом не ленитесь внимательно осмотреть его и убедиться в отсутствии каких-либо «накладок» и посторонних устройств.",
            "Пожалуйста, примите все меры, чтобы вводимый Вами ПИН-код был не заметен для окружающих."
        ],
        "ground_truth": "Чтобы обезопасить себя от съема данных карты в банкомате:\n\nВнимательно осматривайте банкомат перед использованием на наличие подозрительных накладок и посторонних устройств.\nПрикрывайте рукой клавиатуру при вводе ПИН-кода, чтобы его не могли увидеть окружающие."
    }
)

data.append(
    {
        "question": "Почему важно сохранять чеки и квитанции по операциям с картой? И что делать, если в выписке есть операции, которые вы не совершали?",
        "contexts": [
            "Храните Ваши квитанции и чеки в соответствии с условиями заключенного с банком договора и при получении ежемесячной выписки производите выверку ее соответствия указанным документам.",
            "У Вас возникли претензии по списаниям, отраженным в выписке по карточному счету. Вам необходимо в сроки, указанные в Общих условиях выпуска и обслуживания кредитных карт и Общих условиях открытия, ведения и закрытия счетов физических лиц, а также выпуска и обслуживания расчетных карт, обратиться в Банк посредством дистанционного обслуживания и предъявить претензию по оспариваемым операциям."
        ],
        "ground_truth": "Важно сохранять квитанции и чеки по операциям с картой, чтобы при получении выписки можно было сверить ее с реальными операциями и обнаружить расхождения. Если в выписке есть операции, которые вы не совершали, необходимо в установленные сроки обратиться в банк через дистанционное обслуживание и предъявить претензию по этим операциям."
    }
)

data.append(
    {
        "question": "Почему не рекомендуется использовать карту в странах повышенного риска, перечисленных в документе? Приведите две причины.",
        "contexts": [
            "В этих странах высок риск копирования данных Вашей карты и использования их для изготовления подделок. В таких странах для снятия наличных денежных средств рекомендуется использовать банкоматы известных банков, которые установлены в отделениях и крупных торговых центрах."
        ],
        "ground_truth": "Две причины, по которым не рекомендуется использовать карту в странах повышенного риска:\n\nВысокий риск копирования данных карты и изготовления поддельных карт.\nДля снятия наличных лучше использовать банкоматы только известных банков в отделениях и торговых центрах."
    }
)

data.append(
    {
        "question": "При аренде автомобиля на карте блокируется сумма за весь период аренды. Что важно сделать после окончательного расчета, чтобы эта сумма была возвращена?",
        "contexts": [
            "Чтобы этого избежать, после проведения всех расчетов, потребуйте у агентства, предоставившего Вам автомобиль в аренду, отправить в обслуживающий банк уведомление о снятии ранее произведенной блокировки."
        ],
        "ground_truth": "После окончательного расчета при аренде автомобиля важно потребовать у арендодателя отправить в обслуживающий банк уведомление о снятии ранее заблокированной суммы за весь период аренды, чтобы эта сумма была возвращена на карту."
    }
)

data.append(
    {
        "question": "Правда ли, что при бронировании гостиницы по карте вам необходимо сообщить все реквизиты карты, включая ПИН-код? Если нет, то что именно требуется сообщить?",
        "contexts": [
            "При бронировании номера в гостинице по карте Вас попросят сообщить свое имя, номер карты, срок ее действия (иногда, дополнительно — трехзначный код безопасности, напечатанный на обратной стороне карты на полосе для подписи) и срок Вашего пребывания."
        ],
        "ground_truth": "Нет, неправда. При бронировании гостиницы по карте не требуется сообщать ПИН-код. Обычно для бронирования запрашивают ваше имя, номер карты, срок ее действия, иногда трехзначный код безопасности (CVV/CVC) с оборотной стороны карты и планируемый срок пребывания."
    }
)

# %% [markdown]
# #### 2_Перечень документов и сведений, предоставляемых Клиентом (представителем Клиента) для присоединения к условиям Универсального догов.pdf
#
# Перечень документов и сведений, предоставляемых
# Клиентом (представителем Клиента) для присоединения
# к условиям Универсального договора, а также в целях
# обслуживания в рамках Универсального договора
# (далее — Перечень)

# %%
data.append(
    {
        "question": "Если я из другой страны и у меня нет паспорта РФ, что мне делать?",
        "contexts": ["""
                     1. Документы и сведения, получаемые в целях идентификации Клиентов-физических лиц, а также в целях обслуживания таких Клиентов в рамках Универсального договора
                     1.4. Реквизиты документа, удостоверяющего личность: серия (при наличии) и номер документа, дата выдачи документа, наименование органа, выдавшего документ (при наличии кода подразделения может не устанавливаться), и код подразделения (при наличии).
                     1.4.2.для иностранных граждан:
                     •паспорт иностранного гражданина;
                     •дипломатический паспорт, служебный паспорт, удостоверяющие личность иностранного гражданина.""",
                     """.5.Документ, подтверждающий право иностранного гражданина или лица без гражданства на пребывание (проживание) в Российской Федерации (миграционной карты в случае отсутствия иных документов), в случае если наличие таких документов обязательно в соответствии с международными договорами Российской Федерации и законодательством Российской Федерации;Документами, подтверждающими право иностранного гражданина или лица без гражданства на пребывание (проживание) в РФ, являются:
                    •миграционная карта в случае отсутствия иных документов;
                    •вид на жительство;
                    •разрешение на временное проживание;
                    •виза;
                    •иной документ, подтверждающий в соответствии с международными договорами Российской Федерации и законодательством РФ право иностранного гражданина или лица без гражданства на пребывание (проживание) в РФ.
"""],
        "ground_truth": """
                        Если вы из другой страны, то для заключения договора вам неообходимы документы, удостоверяющие Вашу личность. Для иностранных граждан это:
                            •паспорт иностранного гражданина;
                            •дипломатический паспорт, служебный паспорт, удостоверяющие личность иностранного гражданина.
                        Также необходимы документы, подтверждающие право иностранного гражданина (проживание) в Российской Федерации (миграционной карты в случае отсутствия иных документов), в случае если наличие таких документов обязательно в соответствии с международными договорами Российской Федерации и законодательством Российской Федерации;Документами, подтверждающими право иностранного гражданина или лица без гражданства на пребывание (проживание) в РФ, являются:
                            •миграционная карта в случае отсутствия иных документов;
                            •вид на жительство;
                            •разрешение на временное проживание;
                            •виза;
                            •иной документ, подтверждающий в соответствии с международными договорами Российской Федерации и законодательством РФ право иностранного гражданина или лица без гражданства на пребывание (проживание) в РФ. """
    }               
)

data.append(
    {
        "question": "В течении скольких дней действительна выписка из ЕГРЮЛ?",
        "contexts": ["""
                    2.2. Выписка из Единого государственного реестра юридических лиц (ЕГРЮЛ). Банком может быть принята копия 
                    выписки, заверенная регистрирующим органом. Выписка считается действительной для предоставления в Банк 
                    в течение 30 (тридцати) календарных дней с даты ее выдачи и должна содержать актуальные сведения на дату  
                    ее предоставления;"""],
        "ground_truth": "Выписка из Единого государственного реестра юридических лиц (ЕГРЮЛ) действительна в течении 30 дней с даты ее выдачи."
    }
)

data.append(
    {
        "question": "Нужно ли ИП указывать свой сайт для предприятия?",
        "contexts": [
                    """
                    3. Документы и сведения, предоставляемые Клиентом-индивидуальным предпринимателем: 
                    3.5. Сведения о доменном имени, указателе страницы сайта в сети «Интернет», с использованием которых Клиентом 
оказываются услуги (при наличии);
                    """ ],
        "ground_truth": "Да, индивидуальному предпринимателю необходимо указать сведения о доменном имени, указателе страницы сайта в сети «Интернет»."
    }
)

data.append(
    {
        "question": "Может ли Банк запросить дополнительные документы - не из списка обязательных?",
        "contexts": ["""
                     26. Банк может запросить у Клиента, а Клиент обязуется предоставить по запросу Банка дополнительные документы 
                    и сведения, как предусмотренные, так и не предусмотренные настоящим Перечнем, в том числе в целях надлежащей 
                    идентификации Клиента, его представителя, выгодоприобретателя и бенефициарного владельца в соответствии 
                    с требованиями действующего законодательства Российской Федерации, нормативных актов Банка России, а также 
                    требованиями Банка. Банк вправе не запрашивать отдельные документы и сведения, предусмотренные настоящим 
                    Перечнем, в случаях, установленных внутренними правилами Банка."""],
        "ground_truth": "Да, Банк может запросить у Вас дополнительные не предусмотренные Перечнем документы."
    }
)

data.append(
    {
        "question": "Какие документы нужно предоставить физическому лицу для открытия счета?",
        "contexts": [
            "1. Документы и сведения, получаемые в целях идентификации Клиентов-физических лиц, а также в целях обслуживания таких Клиентов в рамках Универсального договора"
        ],
        "ground_truth": "Физическому лицу для открытия счета необходимо предоставить документ, удостоверяющий личность (паспорт или иной документ из списка в п.1.4), документ, подтверждающий регистрацию или место пребывания, ИНН, СНИЛС и контактную информацию."
    }
)

data.append(
    {
        "question": "Какие документы необходимо предоставить юридическому лицу для открытия счета в Банке? Можно ли предоставить сканы документов или нужны оригиналы?",
        "contexts": [
            "2.1. Учредительные документы юридического лица...",
            "2.2. Выписка из Единого государственного реестра юридических лиц (ЕГРЮЛ)...",
            "2.3. Документ об избрании единоличного исполнительного органа юридического лица..."
        ],
        "ground_truth": "Юридическому лицу необходимо предоставить учредительные документы, выписку из ЕГРЮЛ, документ об избрании руководителя, документы, подтверждающие личность руководителя и лиц, имеющих право подписи. Документы можно предоставить в копиях, заверенных нотариально, регистрирующим органом, руководителем или сотрудником Банка при наличии оригиналов."
    }
)

data.append(
    {
        "question": "Можно ли открыть счет индивидуальному предпринимателю – иностранному гражданину? Какие документы для этого нужны?",
        "contexts": [
            "3.1. Идентификация индивидуального предпринимателя осуществляется на основании документов и сведений, указанных в пункте 1.4 настоящего Перечня",
            "3.2. Документ, подтверждающий право иностранного гражданина или лица без гражданства на пребывание (проживание) в Российской Федерации..."
        ],
        "ground_truth": "Да, индивидуальному предпринимателю-иностранному гражданину можно открыть счет. Для этого нужно предоставить документ, удостоверяющий личность, документ, подтверждающий право пребывания/проживания в РФ (напр. миграционную карту), ИНН, СНИЛС, выписку из ЕГРИП и контактную информацию."
    }
)

data.append(
    {
        "question": "Какие документы потребуются, если открывать счет для нотариуса, занимающегося частной практикой? Может ли нотариус быть иностранцем при этом?",
        "contexts": [
            "5.1. Документ, удостоверяющий личность и указанный в пункте 1.4 настоящего Перечня",
            "5.2. Документ, подтверждающий наделение нотариуса полномочиями (назначение на должность), выдаваемый органами юстиции субъектов Российской Федерации, в соответствии с законодательством Российской Федерации"
        ],
        "ground_truth": "Для открытия счета нотариусу, занимающемуся частной практикой, требуется предоставить документ, удостоверяющий личность, документ о назначении на должность нотариуса от органов юстиции, регистрационные документы, финансовые документы и контактные данные. Нотариус может быть иностранцем, в этом случае дополнительно потребуется документ, подтверждающий право на пребывание/проживание в РФ."
    }
)

data.append(
    {
        "question": "Можно ли открыть счет для доверительного управления? Какие для этого нужны документы? Кто будет распоряжаться этим счетом?",
        "contexts": [
            "9.1. Документы, указанные в настоящем Перечне, для открытия счета в зависимости соответствующей категории Клиента (физическое лицо, юридическое лицо и т.п.); 9.2. Договор, на основании которого осуществляется доверительное управление."
        ],
        "ground_truth": "Да, можно открыть счет для доверительного управления. Для этого нужно предоставить стандартный пакет документов в зависимости от организационно-правовой формы доверительного управляющего (физлицо, юрлицо и т.д.), а также договор доверительного управления. Распоряжаться счетом будет доверительный управляющий от имени учредителя управления."
    }
)

data.append(
    {
        "question": "Как узнать, кто является бенефициарным владельцем юридического лица? Какие документы для этого нужны?",
        "contexts": [
            "12. Идентификация бенефициарного(ых) владельца(ев) осуществляется на основании следующий документов и сведений..."
        ],
        "ground_truth": "Для идентификации бенефициарного владельца юридического лица необходимо предоставить документы, удостоверяющие личность бенефициара, документ о регистрации/пребывании в РФ (если бенефициар - иностранец), ИНН, адрес регистрации и контактные данные. Также можно заполнить анкету бенефициарного владельца по форме Банка."
    }
)

data.append(
    {
        "question": "Могут ли представители юридического лица распоряжаться счетом? Какие документы нужны для подтверждения их полномочий?",
        "contexts": [
            "13.3. Подтверждающие наличие у лица полномочий представителя Клиента, — наименование, дата выдачи, срок действия, номер документа (при наличии), на котором основаны полномочия представителя Клиента. Документом, подтверждающим полномочия представителя Клиента, может являться доверенность или иной документ, подтверждающий полномочия и признаваемый таковым."
        ],
        "ground_truth": "Да, представители юридического лица могут распоряжаться счетом от его имени. Для подтверждения их полномочий необходимо предоставить доверенность или иной документ, указывающий полномочия представителя, его ФИО, дату выдачи документа и срок его действия."
    }
)



data.append(
    {
        "question": "Является ли иностранный гражданин - руководитель российской компании представителем этой компании? Если да, то какие документы ему понадобятся?",
        "contexts": [
            "2.5. Документ, удостоверяющий личность физического лица-единоличного исполнительного органа юридического лица, а также уполномоченных лиц юридического лица, которым предоставлено право распоряжаться денежными средствами, находящимися на банковском счете (при наличии таковых) в соответствии с пунктом 1.4 настоящего Перечня."
        ],
        "ground_truth": "Да, иностранный гражданин, являющийся руководителем (единоличным исполнительным органом) российской компании, считается ее представителем. В этом случае ему понадобятся документ, удостоверяющий личность (согласно п.1.4), а также документ, подтверждающий его право на пребывание/проживание в РФ (миграционная карта или иной документ согласно п.1.5)."
    }
)

data.append(
    {
        "question": "Какие документы помогают идентифицировать выгодоприобретателя - адвоката? А если выгодоприобретателем является арбитражный управляющий?",
        "contexts": [
            "23. Идентификация выгодоприобретателей — адвокатов (при наличии) осуществляется на основании документов и сведений, указанных в подпунктах 6.1–6.6 настоящего Перечня...",
            "24. Идентификация выгодоприобретателей — арбитражных управляющих (при наличии) осуществляется на основании документов и сведений, указанных в подпунктах 7.1–7.5 настоящего Перечня..."
        ],
        "ground_truth": "Если выгодоприобретателем является адвокат, то для его идентификации потребуются документ, удостоверяющий личность, регистрационные документы адвоката, регистрационные и контактные данные."
    }
)

# %% [markdown]
# #### 3_Пользовательское соглашение АО «Тинькофф Страхование».pdf
# Пользовательское соглашение АО «Тинькофф Страхование» (далее — Соглашение)

# %%
data.append(
    {
        "question": "Расскажи про термины 'Договор страхования' и 'КАСКО'",
        "contexts": ["""1. Термины и определения     
                    Договор страхования — договор, по которому одна сторона (Страховщик) обязуется за обусловленную договором 
                    плату (страховую премию) при наступлении предусмотренного в договоре события (страхового случая) осуществить 
                    другой стороне (страхователю) или иному лицу, в пользу которого заключен договор (выгодоприобретателю), 
                    страховое возмещение в пределах определенной договором суммы (страховой суммы).""",
                    """КАСКО — комбинированное страхование транспортных средств и сопутствующих рисков."""],
        "ground_truth": """ Да, конечно! Договор страхования — это договор, по которому одна сторона (Страховщик) обязуется за обусловленную договором 
                    плату (страховую премию) при наступлении предусмотренного в договоре события (страхового случая) осуществить 
                    другой стороне (страхователю) или иному лицу, в пользу которого заключен договор (выгодоприобретателю), 
                    страховое возмещение в пределах определенной договором суммы (страховой суммы). 
                    КАСКО — это комбинированное страхование транспортных средств и сопутствующих рисков."""
    }
)

data.append(
    {
        "question": "Какой минимум страховой выплаты мне вернут, если моя страховая сумма = 50 000 долларов?",
        "contexts": """ 
                    2.19.   При добровольном страховании непредвиденных расходов путешественников страховая сумма в договоре 
                    страхования может быть установлена в рублях или иностранной валюте в рублевом эквиваленте по официальному 
                    курсу иностранных валют ЦБ РФ на дату заключения Договора страхования, но не менее чем 66,7 руб. за 1 у.е.  при 
                    страховой сумме 30 000 у.е., 57,2 руб. за 1 у.е. при страховой сумме 35 000 у.е., 50 руб. за 1 у.е. при страховой сумме 
                    50 000 у.е., 26,7 руб. за 1 у.е. при страховой сумме 75 000 у.е.""" ,
        "ground_truth": """ 
                    Минимальная страховая выплата, которую вам вернут, если ваша страховая сумма составляет 50 000 долларов, составляет 50 рублей за 1 доллар США. Минимальная выплата составит 2 500 000 рублей.
                    Обратите внимание, что это минимальная выплата, которую вы получите. Фактическая сумма выплаты может варьироваться в зависимости от условий вашего договора.
        """
    }
)

data.append(
    {
        "question": "При принятии пользовательских соглашений, кому еще попадают мои данные?",
        "contexts": ["""
                    5. Персональные данные     
                        5.1.       Пользователь подтверждает, что с использованием Дистанционных каналов взаимодействия дает Страховщику, 
                        аффилированным лицам страховщика, Страховому агенту или Страховому брокеру, а также лицам, 
                        предоставляющим услуги по использованию их информационных возможностей для целей заключения договоров 
                        страхования, хранения документов, в том числе, облачных сервисов, серверов, программных продуктов, согласие на 
                        обработку его персональных данных с целью осуществления дистанционного взаимодействия с последними при 
                        использовании их Сайта и/или сайтов в сети Интернет или при помощи ПО Страховщика и в целях осуществления 
                        маркетинговых коммуникаций перечисленных лиц с Пользователем. Пользователь подтверждает, что указываемые 
                        им персональные данные третьих лиц предоставляются с полученного им согласия на обработку их персональных 
                        данных Страховщиком, аффилированными лицами Страховщика, Страховым агентом или Страховым брокером в 
                        целях указанных выше. Пользователь подтверждает, что предоставленные им согласия на обработку персональных 
                        данных содержат все необходимые сведения, предусмотренные частью 4 статьи 9 Федерального закона от    
                        27.07.2006 No 152-ФЗ «О персональных данных». Указанное согласие дано на срок 15 (пятнадцать) лет,  а в случае его 
                        отзыва, обработка персональных данных должна быть прекращена АО «Тинькофф Страхование»  и/или третьими 
                        лицами и данные уничтожены при условии прекращения договорных отношений с АО «Тинькофф Страхование» в 
                        срок не позднее 1 (одного) года с момента получения уведомления об отзыве согласия на обработку персональных 
                        данных и прекращения отношений с АО «Тинькофф Страхование».  
        """],
        "ground_truth": """
                    Согласно пункту 5.1 пользовательского соглашения, ваши персональные данные могут быть переданы следующим сторонам:
                        • Аффилированные лица страховщика
                        • Страховой агент
                        • Страховой брокер
                        • Лица, предоставляющие услуги по использованию их информационных возможностей для целей заключения договоров страхования, хранения документов, в том числе облачных сервисов, серверов, программных продуктов
"""
    }
)

data.append(
    {
        "question": "Что такое Пользовательское соглашение АО «Тинькофф Страхование»?",
        "contexts": [
            "Настоящее Соглашение является публичной офертой и определяет условия использования материалов и сервисов, размещенных на официальном сайте АО «Тинькофф Страхование» (далее — Страховщик) в сети Интернет по адресу: tinkoffinsurance.ru, посетителями и пользователями данного интернет-сайта (далее — Сайт), а также условия и порядок дистанционного взаимодействия со Страховщиком с использованием Сайта и/или сайтов в сети Интернет страховых агентов и страховых брокеров Страховщика, а также аффилированных лиц Страховщика и/или их мобильных приложений."
        ],
        "ground_truth": "Пользовательское соглашение АО «Тинькофф Страхование» - это публичная оферта, определяющая условия использования материалов и сервисов на сайте tinkoffinsurance.ru и порядок дистанционного взаимодействия со Страховщиком через сайт и мобильные приложения."
    }
)

data.append(
    {
        "question": "Какое определение дано в документе для простой электронной подписи? Зачем она используется?",
        "contexts": [
            "Простая электронная подпись Пользователя или Клиента Страховщика (далее — ПЭП) — электронная подпись, которая посредством использования кодов или иных средств подтверждает факт формирования и подписания Пользователем или Клиентом Страховщика документов в электронном виде."
        ],
        "ground_truth": "Простая электронная подпись (ПЭП) - это электронная подпись, которая с помощью кодов или иных средств подтверждает факт подписания пользователем документов в электронном виде. Она используется для подписания документов при дистанционном взаимодействии со Страховщиком."
    }
)

data.append(
    {
        "question": "Как пользователь может получить одноразовый код или код доступа для ПЭП? Может ли он поделиться этим кодом с другими?",
        "contexts": [
            "Одноразовый код или Код доступа может быть направлен на номер сотового телефона, предоставленный Пользователю оператором подвижной электросвязи в соответствии с договором на оказание услуг связи и предоставленный Пользователем Страховщику в качестве основного контактного номера для взаимодействия со Страховщиком",
            "Пользователь обязан хранить в тайне ключ ПЭП, а также Логин и пароль, и ни при каких обстоятельствах не передавать его третьим лицам."
        ],
        "ground_truth": "Одноразовый код или код доступа для ПЭП направляется на номер мобильного телефона пользователя, который он предоставил Страховщику в качестве основного контактного номера. Пользователь обязан хранить ключ ПЭП (одноразовый код/код доступа) в тайне и ни при каких обстоятельствах не передавать его третьим лицам."
    }
)

data.append(
    {
        "question": "Зачем страховщик ведет аудио- и видеозапись при взаимодействии с клиентом? Как долго эти записи хранятся?",
        "contexts": [
            "При заключении Договоров страхования, а также при ином обращении Клиента или Пользователя к Страховщику или его представителям Страховщик вправе осуществлять наблюдение, фотографирование, аудио- и видеозапись, включая запись телефонных разговоров, а также копирование и хранение переписок между Пользователем и Страховщиком (его представителями) по электронной почте или в мессенджерах, без дополнительного уведомления Клиента (Пользователя) о такой записи. Клиент соглашается, что Страховщик вправе хранить такие записи в течение 5 (пяти) лет с момента прекращения отношений с Клиентом (Пользователем), с целью улучшения качества обслуживания, исполнения Договора страхования, а также использовать их при проведении любых расследований в связи с Договором страхования."
        ],
        "ground_truth": "Страховщик ведет аудио-, видеозапись, фотографирование, копирует переписку с клиентом без дополнительного уведомления с целью улучшения качества обслуживания, исполнения договора страхования, а также для использования этих записей при проведении расследований, связанных с договором. Такие записи страховщик вправе хранить в течение 5 лет с момента прекращения отношений с клиентом."
    }
)

data.append(
    {
        "question": "В каких случаях застрахованному могут быть оплачены планируемые расходы по страховому случаю до предоставления подтверждающих документов? Какие ограничения есть по размеру таких выплат?",
        "contexts": [
            "По договорам добровольного страхования непредвиденных расходов путешественников по предварительному согласованию со Страховщиком Застрахованному могут оплачиваться планируемые расходы по предусмотренным договором страхования страховым событиям, предусматривающим возмещение расходов на оказание Экстренной или Неотложной амбулаторной и/или стационарной помощи, с условием предоставления Застрахованным документов, подтверждающих такие расходы Страховщику непосредственно после их несения (чеки, платежные документы и пр.). В случае если в результате страхового случая Застрахованным лицом были понесены соответствующие расходы на оказание Экстренной или Неотложной амбулаторной и/или стационарной помощи, в том числе, предварительно согласованные Страховщиком, но не были предоставлены документы, подтверждающие их оплату, Страховщик возмещает расходы в размере не более 200 у.е. (если страховая сумма установлена в валюте, отличной от российского рубля) или 10 000 российских рублей (если страховая сумма установлена в российских рублях), за один страховой случай."
        ],
        "ground_truth": "По договорам добровольного страхования непредвиденных расходов путешественников застрахованному могут быть оплачены планируемые расходы по страховым случаям, предусматривающим возмещение расходов на экстренную/неотложную амбулаторную или стационарную помощь, по предварительному согласованию со страховщиком. Условие - предоставление подтверждающих документов сразу после несения расходов. Если документы не предоставлены, то страховщик возмещает расходы в размере не более 200 у.е. (если страховая сумма в валюте) или 10 000 рублей (если в рублях) за один случай."
    }
)

data.append(
    {
        "question": "На какой срок пользователь дает согласие на обработку своих персональных данных страховщику? Какие сведения должно содержать согласие на обработку персданных?",
        "contexts": [
            "Указанное согласие дано на срок 15 (пятнадцать) лет, а в случае его отзыва, обработка персональных данных должна быть прекращена АО «Тинькофф Страхование» и/или третьими лицами и данные уничтожены при условии прекращения договорных отношений с АО «Тинькофф Страхование» в срок не позднее 1 (одного) года с момента получения уведомления об отзыве согласия на обработку персональных данных и прекращения отношений с АО «Тинькофф Страхование». Пользователь подтверждает, что предоставленные им согласия на обработку персональных данных содержат все необходимые сведения, предусмотренные частью 4 статьи 9 Федерального закона от 27.07.2006 № 152-ФЗ «О персональных данных»."
        ],
        "ground_truth": "Пользователь дает согласие на обработку своих персональных данных страховщику на срок 15 лет. Пользователь подтверждает, что предоставленные им согласия на обработку персданных содержат все необходимые сведения, предусмотренные ч.4 ст.9 ФЗ 'О персональных данных', к которым относятся цель обработки персданных, перечень действий с ними, срок действия согласия и условие его отзыва."
    }
)

data.append(
    {
        "question": "Куда пользователь может направить обращение при возникновении вопросов или спора со страховщиком?",
        "contexts": [
            "При возникновении вопросов или спора можно отправить обращение:\n\nв АО «Тинькофф Страхование» по почте по адресу: 127287, Российская Федерация, г. Москва, ул. 2-я Хуторская, дом 38А, строение 26, либо путем заполнения соответствующей формы на сайте Страховщика;\nк финансовому уполномоченному путем регистрации обращения на сайте — finombudsman.ru или по почтовому адресу: 119017, г. Москва, Старомонетный пер., дом 3;\nво Всероссийский союз страховщиков на сайте — ins-union.ru, приложив к обращению необходимые документы и сведения, либо на почтовый адрес: 115093, г. Москва, ул. Люсиновская, д. 27, стр. 3;\nв Центральный Банк Российской Федерации (Банк России) через интернет-приемную на официальном сайте — cbr.ru, приложив к обращению необходимые документы и сведения, либо на почтовый адрес: 107016, г. Москва, ул. Неглинная, д. 12."
        ],
        "ground_truth": "При возникновении вопросов или спора с АО 'Тинькофф Страхование' пользователь может направить обращение:\n\n - В АО 'Тинькофф Страхование' по почте или через форму на сайте;\n - Финансовому уполномоченному на сайте finombudsman.ru или почтовым адресом;\n - Во Всероссийский союз страховщиков на сайте ins-union.ru или почтовым адресом;\nВ Центральный Банк РФ через интернет-приемную на сайте cbr.ru или почтовым адресом."
    }
)

data.append(
    {
        "question": "Где можно ознакомиться с дополнительной информацией и документами о деятельности АО 'Тинькофф Страхование'?",
        "contexts": [
            "Дополнительная информация и документы о деятельности Страховщика в соответствии с п. 6.1 Закона РФ от 27.11.1992 N 4015-1 «Об организации страхового дела в Российской Федерации» и п. 2.1.1. «Базового стандарта защиты прав и интересов физических и юридических лиц — получателей финансовых услуг, оказываемых членами саморегулируемых организаций, объединяющих страховые организации» размещены по ссылкам: tinkoffinsurance.ru/about, tinkoffinsurance.ru/about/documents."
        ],
        "ground_truth": "Дополнительная информация и документы о деятельности АО 'Тинькофф Страхование' в соответствии с законом 'Об организации страхового дела в РФ' и базовым стандартом защиты прав получателей финансовых услуг размещены на сайте страховщика по ссылкам tinkoffinsurance.ru/about и tinkoffinsurance.ru/about/documents."
    }
)

# %% [markdown]
# #### 4 Правила оказания сервиса «Покупка/продажа слитков драгоценных металлов»

# %%
data.append(
    {
        "question": "Что означает 'Партия' и вообще 'Слиток' для драгоценных металлов?",
        "contexts": ["""
                    Партия — приобретенные Клиентом Слитки в количестве, превышающем 1 (одну) штуку, и подлежащие доставке Клиенту, 
                    в рамках одной Заявки""",
                    """ Слиток — аффинированный драгоценный металл: золото, серебро, платина и палладий в виде слитков (стандартных, 
                    мерных), соответствующих установленным в Российской Федерации стандартам или международным стандартам качества, 
                    изготовленных и маркированных организацией, осуществляющей аффинаж драгоценного металла. Слиток в рамках 
                    предоставления Сервиса доставляется / принимается на хранение в ненарушенной Упаковке с приложением Сертификата-
                    ярлыка (при наличии) и Сертификата качества слитка"""],
        "ground_truth": """Давайте разберемся! 
                    Партия — это приобретенные клиентом слитки в количестве, превышающем 1 штуку, и подлежащие доставке клиенту, в рамках одной заявки.
                    Слиток — это аффинированный драгоценный металл: золото, серебро, платина и палладий в виде слитков (стандартных, 
                    мерных), соответствующих установленным в Российской Федерации стандартам или международным стандартам качества, 
                    изготовленных и маркированных организацией, осуществляющей аффинаж драгоценного металла. Слиток в рамках 
                    предоставления Сервиса доставляется / принимается на хранение в ненарушенной Упаковке с приложением Сертификата-
                    ярлыка (при наличии) и Сертификата качества слитка.
        """
    }
)

data.append(
    {
        "question": "Меня действительно должны фотографировать после полкчения слитка? Какой это пункт в соглашении?",
        "contexts": ["""
                    2.13.12. После подтверждения получения Клиентом/Доверенным лицом Слитка Представитель фотографирует Клиента/
                    Доверенное лицо с полученным Слитком в ненарушенной заводской упаковке и документом, удостоверяющим личность 
                    Клиента/Доверенного лица"""],
        "ground_truth": "Да, Вас действительно должнен сфотографировать Представитель в соответсвии с пунктом 2.13.12."
    }
)

data.append(
    {
        "question": "Какие условия хранения?",
        "contexts": [""" 
                    2.14.9. Условия хранения: температура воздуха от +17 до +25 °С, атмосферное давление от 740 до 760 мм рт. ст., относительная 
                    влажность воздуха от 30 до 60%"""],
        "ground_truth": """
                    В соответсвии с пунктом 2.14.9. условия хранения слитка слудующие: 
                        - температура воздуха от +17 до +25 °С,
                        - атмосферное давление от 740 до 760 мм рт. ст.,
                        - относительная влажность воздуха от 30 до 60% """
    }
)

data.append(
    {
        "question": "Зачем нужна эта доверенность?",
        "contexts": ["Приложение № 5 к Правилам предоставления Сервиса Форма доверенности Доверенность Клиент, обращаясь с заявкой в рамках сервиса «Покупка/продажа слитков драгоценных металлов» (далее — «Представляемый») и предоставляя Банку посредством Дистанционного обслуживания данные своего представителя (фамилия, имя, отчество представителя полностью, дата рождения, серия и номер паспорта, кем и когда выдан), выдает настоящую доверенность, которой уполномочивает своего представителя представлять интересы Представляемого и выступать от имени Представляемого в отношениях с АО «Тинькофф Банк» (далее — Банк) в рамках сервиса «Покупка/продажа слитков драгоценных металлов»."],
        "ground_truth": "Эта доверенность нужна, чтобы клиент мог уполномочить своего представителя действовать от его имени при получении слитков драгоценных металлов с ответственного хранения в Тинькофф Банке."
    }
)

data.append(
    {
        "question": "На какой срок выдается эта доверенность? Можно ли ее передоверить другому лицу?",
        "contexts": ["Датой выдачи доверенности считается дата предоставления Представляемым Банку данных своего представителя. Доверенность выдана сроком на 1 (один) год, полномочия по настоящей доверенности не могут быть передоверены другим лицам."],
        "ground_truth": "Доверенность выдается сроком на 1 год. Полномочия по этой доверенности нельзя передоверять другим лицам."
    }
)

data.append(
    {
        "question": "Что такое 'Сертификат качества слитка'?",
        "contexts": ["Сертификат качества слитка — документ о качестве драгоценного металла, содержащий сведения о соответствии драгоценного металла стандартам качества, технические характеристики и параметры Слитка, информацию о химическом составе, произведенный/заверенный предприятием-изготовителем Слитка."],
        "ground_truth": "Сертификат качества слитка - это документ, выданный изготовителем слитка драгоценного металла, который содержит информацию о соответствии металла стандартам качества, его технические характеристики, параметры и химический состав."
    }
)

data.append(
    {
        "question": "Как клиент может получить сертификат качества слитка, который он передал на хранение в банк?",
        "contexts": ["По требованию Клиента Банк предоставляет Клиенту заверенную Банком копию Сертификата качества слитка, переданного на ответственное хранение."],
        "ground_truth": "По требованию клиента банк предоставляет ему заверенную копию сертификата качества слитка, который клиент передал на ответственное хранение в банке."
    }
)

data.append(
    {
        "question": "Какие условия хранения слитков в банке? Где их хранят?",
        "contexts": ["Хранение Банком Слитка Клиента осуществляется в хранилище 5 (Пятого) класса устойчивости к взлому, оборудованном системой видеонаблюдения и охранно-пожарной и тревожной сигнализации с выводом сигнала на пункт централизованной охраны, с осуществлением физической круглосуточной специализированной охраны хранилища.", "Условия хранения: температура воздуха от +17 до +25 °С, атмосферное давление от 740 до 760 мм рт. ст., относительная влажность воздуха от 30 до 60%."],
        "ground_truth": "Слитки хранятся в специальном хранилище 5 класса устойчивости к взлому, оборудованном системами видеонаблюдения, охранно-пожарной и тревожной сигнализацией, а также круглосуточной охраной. Условия хранения: температура +17...+25°С, атмосферное давление 740-760 мм рт.ст., влажность 30-60%."
    }
)

data.append(
    {
        "question": "Можно ли вернуть слиток в банк, если при получении были обнаружены его повреждения? Как это сделать?",
        "contexts": ["В случае обнаружения при приеме Слитка с ответственного хранения от Представителя нарушения целостности заводской упаковки Слитка, несоответствия нанесенной на Слиток маркировки данным, указанным в Сертификате качества слитка и/или Сертификате-ярлыке, отсутствия либо повреждения Сертификата качества слитка и/или Слитка (наличие на поверхности Слитка наплывов / заусенцев / царапин / жировых пятен / посторонних включений) Клиентом/Доверенным лицом и Представителем оформляется в двух экземплярах Рекламационный акт по форме Приложения № 3 к настоящим Правилам, в котором фиксируются указанные выше нарушения / несоответствия / повреждения. В случае наличия указанных выше нарушений / несоответствий / повреждений Слиток вместе с Сертификатом качества слитка и Сертификатом-ярлыком вкладываются Клиентом/Доверенным лицом в порожний сейф-пакет и запечатываются, после чего сейф-пакет помещается в Устройство для перевозки слитка с дальнейшим опломбированием номерной разовой пломбой. Номер сейф-пакета, а также номерной разовой пломбы отражаются в Рекламационном акте."],
        "ground_truth": "Да, если при получении слитка с хранения были обнаружены его повреждения или нарушения упаковки, несоответствия маркировки и т.п., то клиент/доверенное лицо вместе с представителем банка оформляют рекламационный акт в двух экземплярах. В этом акте фиксируются все нарушения. После этого слиток вместе с сертификатами запечатывают в новый сейф-пакет и опломбировывают, указав номера на рекламационном акте. Затем слиток возвращается обратно в банк."
    }
)

data.append(
    {
        "question": "Кто может стать доверенным лицом клиента?",
        "contexts": ["Доверенное лицо — физическое лицо, уполномоченное Клиентом, которому предоставлено право на представление интересов Клиента и осуществление действий от его имени в рамках Сервиса на основании доверенности, оформленной посредством Дистанционного обслуживания в соответствии с п. 5.3 настоящих Правил по форме Приложения № 5 к настоящим Правилам."],
        "ground_truth": "Доверенным лицом клиента может стать любое физическое лицо, которому клиент предоставит полномочия представлять его интересы в рамках сервиса покупки/продажи слитков драгоценных металлов. Доверенность на это лицо оформляется клиентом посредством дистанционного обслуживания в банке по форме из Приложения №5 к Правилам."
    }
)

data.append(
    {
        "question": "Можно ли поменять доверенное лицо? Как это сделать?",
        "contexts": ["Клиент может отменить выданную доверенность путем обращения в Банк посредством Дистанционного обслуживания в любое время, но не позднее одного дня до планируемой даты встречи с представителем Клиента."],
        "ground_truth": "Да, клиент может отменить ранее выданную доверенность на доверенное лицо. Для этого он должен обратиться в банк посредством дистанционного обслуживания не позднее чем за 1 день до планируемой даты встречи с действующим доверенным лицом."
    }
)

data.append(
    {
        "question": "Что такое 'Опись' в контексте этих Правил?",
        "contexts": ["Опись — опись ценностей, вложенных в сейф-пакет для доставки Клиенту, оформленная Банком на доставляемый Клиенту в рамках сделки купли-продажи / при возврате с ответственного хранения: Слиток, Сертификат-ярлык и Сертификат качества слитка (по форме Приложения №2 к настоящим Правилам)."],
        "ground_truth": "Опись - это документ, оформляемый банком на слиток, сертификат-ярлык и сертификат качества слитка, которые вкладываются в сейф-пакет для доставки клиенту при совершении сделки купли-продажи слитка или при возврате слитка с хранения. В описи указывается содержимое сейф-пакета."
    }
)

data.append(
    {
        "question": "Как происходит покупка слитка у клиента банком? Есть ли какие-то особые условия?",
        "contexts": ["Банк приобретает у Клиента только Слитки, находящиеся на ответственном хранении в Банке.", "Клиент, обращаясь с Заявкой, подтверждает, что на момент заключения договора купли-продажи Слиток принадлежит на праве собственности Клиенту, не продан, не является предметом залога, не обременен правами третьих лиц, в споре, под арестом и иным запрещением не состоит."],
        "ground_truth": "Банк осуществляет покупку слитков драгоценных металлов только у тех клиентов, чьи слитки находятся на ответственном хранении в самом банке. При подаче заявки на продажу слитка клиент должен подтвердить, что на момент продажи слиток принадлежит ему на праве собственности, не продан, не заложен, не арестован и не обременен правами третьих лиц."
    }
)

# %% [markdown]
# #### 5_Условия комплексного банковского обслуживания физических лиц.pdf

# %%
data.append(
    {
        "question": "Что такое накопительный счет и как начисляются проценты?",
        "contexts": ["""
                    3.1. Начисление процентов на остаток средств по Счету вклада/Накопительному счету производится со дня, следующего 
                    за днем зачисления денежных средств на Счет вклада/Накопительный счет Клиента, до дня окончания срока Вклада 
                    (включительно) либо до их списания со Счета вклада/Накопительного счета по иным основаниям.""",
                    """ 
                    3.3. Клиент имеет возможность по согласованию с Банком посредством Дистанционного обслуживания изменить Тарифный 
                    план Вклада на Тарифный план для мультивалютного Вклада. При смене Тарифного плана изменения в части процентной 
                    ставки по Счету вклада, изначально открытого в рамках текущего Договора вклада, не распространяются до конца срока 
                    размещения, установленного предыдущим Тарифным планом. Процентные ставки по валютам, отличным от валюты 
                    измененного Тарифного плана, устанавливаются новым Тарифным планом.
                    3.4. При начислении процентов в расчет принимается величина процентной ставки (в процентах годовых) и фактическое 
                    количество календарных дней, на которое привлечены денежные средства. При этом за базу берется действительное 
                    число календарных дней в году (365 или 366 дней соответственно).
                    """,
                    """ 
                    Накопительный счет — счет, на котором учитываются денежные средства Клиента, предусматривающий начисление 
                    процентов на остаток денежных средств, в соответствии с Договором накопительного счета."""],
        "ground_truth": 
                    """
                    Накопительный счет - это счет, на котором учитываются денежные средства клиента и на который начисляются проценты на остаток денежных средств. Проценты начисляются в соответствии с условиями договора накопительного счета.
                    Проценты на накопительном счете начисляются со дня, следующего за днем зачисления денежных средств на счет, до дня окончания срока вклада (включительно) либо до их списания со счета по другим основаниям.

                    При начислении процентов учитываются:
                    • Величина процентной ставки (в процентах годовых)
                    • Фактическое количество календарных дней, на которое привлечены денежные средства

                    За базу берется действительное число календарных дней в году (365 или 366 дней соответственно)."""
    }
)

data.append(
    {
        "question": "Можно ли открыть вклад в 12 лет?",
        "contexts": ["1.2. Банк не заключает Договор вклада (Договор накопительного счета) с лицами, не достигшими возраста 14 лет"],
        "ground_truth": "Нет, Банк не заключает договор вклада с лицами, не достигшими возраста 14 лет."
    }
)

data.append(
    {
        "question": "Могу ли я открыть несколько вкладов и пополнять их?",
        "contexts": ["""
                    4.1. Клиент имеет право:
                    4.1.1. Предъявить Банку требование о досрочном полном или частичном изъятии Вклада.
                    4.1.2. Вносить дополнительные денежные средства во Вклад/Накопительный счет, если данная возможность установлена 
                    Тарифным планом.
                    4.1.3. Разместить несколько Вкладов (открыть несколько Счетов вклада/Накопительных счетов на условиях, устанавливаемых 
                    Договором вклада (Договором накопительного счета), Тарифами:
                    • через Дистанционное обслуживание;
                    • в офисе Банка в часы работы операционного подразделения Банка.
"""],
        "ground_truth": """ 
                    Да, вы можете открыть несколько вкладов и пополнять их.
                    Согласно пункту 4.1.3 приведенного контекста, клиент имеет право разместить несколько вкладов (открыть несколько счетов вклада/накопительных счетов) на условиях, устанавливаемых договором вклада (договором накопительного счета) и тарифами.
                    Вы можете открыть несколько вкладов как через дистанционное обслуживание, так и в офисе банка в часы работы операционного подразделения банка."""
    }
)

data.append(
    {
        "question": "Дают ли кредит на автомобиль?",
        "contexts": ["3.1. Банк предоставляет Клиенту Кредит на потребительские цели, в том числе на приобретение Товара и/или Автомобиля, в соответствии с законодательством Российской Федерации."],
        "ground_truth": "Да, в соответсвии с пунктом 3.1. Банк предоставляет Клиенту Кредит на потребительские цели, , в том числе на приобретение автомобиля."
    }
)

data.append(
    {
        "question": "Распростроняется ли страховое покрытие на смерть в алкогольном опьянении?",
        "contexts": [""" 
                    Страховое покрытие по рискам «Смерть» и «Инвалидность» не распространяется на события, произошедшие в результате 
                    и/или в период:
                    a. действий, совершенных Застрахованным лицом в состоянии алкогольного, наркотического и/или токсического 
                    опьянения; в результате употребления им наркотических, сильнодействующих лекарственных препаратов 
                    и психотропных веществ без предписания врача (или по предписанию врача, но с нарушением указанной  
                    им дозировки); болезни Застрахованного лица, прямо связанной с наркоманией, токсикоманией, хроническим 
                    алкоголизмом
                    """],
        "ground_truth": "Нет, страховое покрытие не распространяется на смерть в алкогольном опьянении."
    }
)

data.append(
    {
        "question": "Для получения страховой выплаты в случае несчастного случая с летальным исходом нужна ли справка из психушки?",
        "contexts": ["""
                    6.1. По риску Смерть в результате Несчастного случая должны быть предоставлены следующие документы:
                    j. Справка из психоневрологического диспансера и наркологического диспансера"""],
        "ground_truth": "Да, в таком случае необходимы справки из психоневрологического диспансера и наркологического диспансера."
    }
)

data.append(
    {
        "question": "Может ли Банк изменить Тарифный план по кредитной карте, и какие условия должны быть соблюдены для этого?",
        "contexts": ["""
                    Банк вправе в одностороннем порядке изменить Тарифный план, применяемый
в рамках Договора, и/или заменить его на другой Тарифный план, в том числе при заключении Договора и/или
на определенный период времени по усмотрению Банка, с целью уменьшения процентной ставки по кредиту
и/или улучшения иных условий обслуживания при условии, что это не повлечет возникновение новых или увеличение размера существующих денежных обязательств Клиента
                    """],
        "ground_truth": "Да, Банк может изменить Тарифный план по кредитной карте в одностороннем порядке, но при условии, что это не приведет к возникновению новых или увеличению уже существующих денежных обязательств клиента "
    }
)


data.append(
    {
        "question": "Какие действия необходимо предпринять клиенту, если он не получил выписку по кредитной карте в установленный срок?",
        "contexts": [
            "При неполучении Выписки в течение 10 (десяти) календарных дней с даты формирования Выписки Клиент обязан обратиться в Банк по телефону для получения информации о сумме Минимального платежа и дате его оплаты. Неполучение Выписки не освобождает Клиента от выполнения им своих обязательств по Договору кредитной карты."
        ],
        "ground_truth": "Клиент должен обратиться в Банк по телефону для получения информации о минимальном платеже и его сроках оплаты, если он не получил выписку в течение 10 календарных дней после её формирования. Не получение выписки не освобождает клиента от обязательств по договору кредитной карты."
    }
)

data.append(
    {
        "question": "Что происходит с денежными средствами, если у Банка возникают сомнения в источнике их происхождения?",
        "contexts": [
            "В случае, если при поступлении в Банк денежных средств, предназначенных Клиенту, у Банка возникают сомнения в источнике их происхождения и/или правовом основании для их перечисления Клиенту, Банк осуществляет зачисление этих денежных средств на отдельный счет…"
        ],
        "ground_truth": "Если у Банка возникают сомнения относительно источника происхождения денежных средств, он зачисляет их на отдельный счет на срок до пяти рабочих дней, в течение которых клиент должен предоставить документы, подтверждающие источник происхождения денежных средств."
    }
)

data.append(
    {
        "question": "Может ли клиент использовать мобильное приложение банка для управления своими счетами и какие операции он может там выполнять?",
        "contexts": [
            "Мобильное приложение Банка — приложение для мобильного устройства, позволяющее осуществлять взаимодействие Банка и/или его партнеров и Клиента, включая обмен информацией и совершение отдельных операций по усмотрению Банка."
        ],
        "ground_truth": "Да, клиент может использовать мобильное приложение банка для управления своими счетами. Через приложение доступны такие операции, как обмен информацией с банком и его партнерами, а также выполнение различных финансовых операций, выбор которых зависит от усмотрения банка."
    }
)

data.append(
    {
        "question": "Какие меры принимает банк для обеспечения безопасности аутентификационных данных клиента?",
        "contexts": [
            "Компрометация — утрата Кодов доступа или Аутентификационных данных, подозрение утраты Кодов доступа или Аутентификационных данных, или возникновение подозрения о доступе третьих лиц к Кодам доступа или Аутентификационным данным."
        ],
        "ground_truth": "Банк принимает различные меры для обеспечения безопасности аутентификационных данных клиента, включая защиту от их компрометации. В случае утери, подозрения на утерю или доступа третьих лиц к этим данным, банк может предпринимать соответствующие шаги для защиты учетной записи клиента и предотвращения несанкционированного доступа."
    }
)

data.append(
    {
        "question": "Что такое операционное время в контексте банковских операций, и как это время регулируется?",
        "contexts": [
            "Операционное время — установленная Банком часть рабочего дня, в течение которого Банк принимает и исполняет поручения Клиентов. Информация об Операционном времени размещается на сайте Банка в сети Интернет."
        ],
        "ground_truth": "Операционное время — это определенный период рабочего дня, в течение которого банк обрабатывает и исполняет поручения клиентов. Это время устанавливается банком и регулируется его внутренними правилами и процедурами. Информация об операционном времени обычно доступна на официальном сайте банка."
    }
)


data.append(
    {
        "question": "Что такое 'Регулярный платеж' согласно документу?",
        "contexts": ["«Регулярный платеж — сумма денежных средств, которую Клиент обязан направлять в погашение Задолженности по Кредитному договору. Регулярный платеж может включать в себя часть Кредита и/или проценты, начисленные за пользование Кредитом.»"],
        "ground_truth": "Регулярный платеж - это сумма, которую Клиент должен периодически выплачивать для погашения задолженности по Кредитному договору. Он может включать в себя часть основного кредита и/или начисленные проценты."
    }
)

data.append(
    {
        "question": "Можно ли внести частичное досрочное погашение кредита? И как это повлияет на остаток задолженности?",
        "contexts": ["«Клиент имеет право досрочно погасить Задолженность с уплатой Банку суммы непогашенного Кредита и начисленных процентов, а также (если применимо) комиссий и плат, предусмотренных Тарифным планом, в любой момент путем зачисления необходимой суммы денежных средств на Картсчет (Счет) и извещения Банка о необходимости проведения досрочного погашения. В случае частичного досрочного погашения уменьшается срок Кредита или сумма Регулярного платежа по выбору Клиента, при этом Клиент не освобождается от оплаты ближайшего Регулярного платежа, а также применимых комиссий и плат, предусмотренных Тарифным планом.», «При обращении Клиента в Банк для совершения частичного досрочного погашения до или в дату оплаты ближайшего Регулярного платежа Клиенту может быть предложено совершить частичное досрочное погашение с погашением ближайшего Регулярного платежа и последующим уменьшением срока Кредита или суммы Регулярного платежа по выбору Клиента.»"],
        "ground_truth": "Да, Клиент имеет право совершить частичное досрочное погашение кредита. При этом по выбору Клиента уменьшится либо срок кредита, либо сумма регулярного платежа. Однако Клиент не освобождается от оплаты ближайшего регулярного платежа и применимых комиссий."
    }
)

data.append(
    {
        "question": "Как часто Банк направляет Клиенту выписку по кредиту? И что произойдет, если Клиент ее не получит?",
        "contexts": ["«Банк ежемесячно формирует и направляет Клиенту Выписку. О числе месяца, в который формируется Выписка, Клиент уведомляется в Оферте. Если соответствующее число в текущем месяце отсутствует, Выписка формируется в последний календарный день месяца.»", "«Неполучение Клиентом Выписки или отказ от ее получения не освобождает Клиента от обязанности погасить Задолженность в полном объеме.»"],
        "ground_truth": "Банк формирует и направляет Клиенту выписку ежемесячно. Даты формирования выписки указываются в Оферте. Если Клиент по какой-то причине не получил выписку, это не освобождает его от обязанности полностью погасить задолженность по кредиту."
    }
)

data.append(
    {
        "question": "Что будет в случае просрочки платежа по кредиту? И какой штраф может быть начислен?",
        "contexts": ["«В случае неоплаты платежа Клиент должен уплатить штраф за неоплату Минимального платежа согласно Тарифному плану. Банк рассматривает любой поступивший платеж Клиента как признание Клиентом данного штрафа в размере поступившего платежа, но не более суммы штрафа, определенного в соответствии с Тарифами.»"],
        "ground_truth": "В случае неоплаты минимального платежа по кредиту, Клиент должен уплатить штраф в соответствии с Тарифным планом. Размер штрафа определяется Тарифами, и любой поступивший от Клиента платеж Банк будет рассматривать как оплату штрафа в пределах установленной суммы."
    }
)

data.append(
    {
        "question": "Можно ли на время приостановить выплаты по кредиту? И как это повлияет на начисление процентов?",
        "contexts": ["«На основании обращения Клиента и по согласованию с Банком на период от 1 (одного) до 12 (двенадцати) месяцев возможно приостановление обязанности Клиента по погашению Задолженности, по оплате Регулярных платежей и/или иных платежей. В указанный период Банк вправе приостановить начисление процентов и иных сумм, предусмотренных Договором реструктуризации задолженности.»"],
        "ground_truth": "Да, на основании обращения Клиента и по согласованию с Банком возможно приостановить обязанность по погашению задолженности и оплате платежей на срок от 1 до 12 месяцев. В этот период Банк вправе также приостановить начисление процентов и иных сумм по кредиту."
    }
)


data.append(
    {
        "question": "Я тут никак не могу понять, что такое ПИН-код для кредитной карты? И зачем он нужен?",
        "contexts": ["«3.9. В целях идентификации Держателя при проведении операций с использованием Кредитной карты/Токена Клиенту предоставляется ПИН-код. ПИН-код является аналогом собственноручной подписи Держателя. Клиент соглашается, что использование Кредитной карты/Токена и правильного ПИН-кода является надлежащей и достаточной идентификацией Держателя Кредитной карты/Токена.»"],
        "ground_truth": "ПИН-код - это персональный идентификационный номер, который используется для идентификации держателя кредитной карты при совершении операций. ПИН-код является аналогом собственноручной подписи и необходим для предотвращения несанкционированного использования карты."
    }
)

data.append(
    {
        "question": "Я хочу оформить дополнительную карту на супругу. Как это сделать? И будет ли она иметь доступ к общему лимиту по кредитке?",
        "contexts": ["«3.2. По заявлению Клиента, переданному в Банк на бумажном носителе или через Дистанционное обслуживание, в рамках Договора кредитной карты Банком может быть выпущена одна или несколько дополнительных Кредитных карт.»", "«3.5. Клиент вправе установить лимит для проведения расходных операций с использованием Кредитной карты.»"],
        "ground_truth": "Вы можете оформить дополнительную кредитную карту на супругу, подав заявление в банк на бумажном носителе или через дистанционное обслуживание. Дополнительная карта будет иметь доступ к общему лимиту задолженности по вашей основной кредитной карте, однако вы можете установить отдельный лимит для расходных операций по дополнительной карте."
    }
)

data.append(
    {
        "question": "А что если я потеряю карту? Сколько у меня есть времени, чтобы ее заблокировать? И как вообще это делается? Через приложение или звонить надо?",
        "contexts": ["«6.1. При обнаружении утери, кражи или порчи Кредитной карты и/или возникновения подозрений, что Кредитная карта или ее реквизиты, а также ПИН-код, QR-код, Коды доступа, Аутентификационные данные, Абонентский номер, Абонентское устройство могли быть утрачены или похищены, а также в случае изъятия Кредитной карты в банкомате или торгово-сервисном предприятии и в случае изменения имени или фамилии Держателя Клиент должен незамедлительно уведомить Банк по телефонам 8 800 555-10-10 или +7 495 645-59-19 (круглосуточно) и заблокировать Кредитную карту и/или Интернет-Банк и/или Мобильный банк, а также подать заявление о досрочном перевыпуске Кредитной карты.»"],
        "ground_truth": "В случае утери или кражи кредитной карты, вы должны незамедлительно уведомить банк по телефонам горячей линии 8 800 555-10-10 или +7 495 645-59-19 (круглосуточно) и заблокировать карту. Также необходимо подать заявление на досрочный перевыпуск новой карты. Чем быстрее вы заблокируете карту, тем меньше риск несанкционированного использования."
    }
)

data.append(
    {
        "question": "Не понял я одну штуку, как это платить проценты по кредиту всегда? Разве беспроцентный период не предусмотрен? Или это уже отменили?",
        "contexts": ["«5.6. На сумму предоставленного Кредита Банк начисляет проценты. Проценты начисляются по ставкам, указанным в Тарифном плане, до дня формирования Заключительного счета включительно.»", "«30 из 74 Годовая/Ежемесячная плата — Плата за обслуживание Кредитной карты.", "...", "Плата — плата за Дополнительные услуги, списываемая Банком в счет Лимита задолженности, на которую распространяется действие беспроцентного периода кредитования согласно Тарифному плану.»"],
        "ground_truth": "В документе указано, что существуют Платы, на которые распространяется действие беспроцентного периода кредитования согласно Тарифному плану. То есть беспроцентный период все же предусмотрен, однако он применяется только к определенным Платам за дополнительные услуги, а на основную сумму кредита проценты начисляются постоянно по ставкам, указанным в Тарифном плане."
    }
)

data.append(
    {
        "question": "Прочитал тут у вас про блокировку карточки. А если я её забуду забрать в банкомате, что тогда делать?",
        "contexts": ["«6.1. [...] а также в случае изъятия Кредитной карты в банкомате или торгово-сервисном предприятии и в случае изменения имени или фамилии Держателя Клиент должен незамедлительно уведомить Банк по телефонам 8 800 555-10-10 или +7 495 645-59-19 (круглосуточно) и заблокировать Кредитную карту и/или Интернет-Банк и/или Мобильный банк, а также подать заявление о досрочном перевыпуске Кредитной карты.»"],
        "ground_truth": "Если вы забыли карту в банкомате, вам необходимо незамедлительно сообщить об этом в банк по телефонам горячей линии 8 800 555-10-10 или +7 495 645-59-19 и заблокировать кредитную карту, а также подать заявление на ее досрочный перевыпуск. Это позволит предотвратить возможное несанкционированное использование забытой карты третьими лицами."
    }
)

data.append(
    {
        "question": "А есть ли какие-то льготные условия, если я захочу приостановить выплаты по кредитке на какое-то время? Например, на ремонт или что-то в этом роде?",
        "contexts": ["«5.15. На основании обращения Клиента и по согласованию с Банком на период от 1 (одного) до 12 (двенадцати) месяцев возможно приостановление обязанности Клиента по погашению Задолженности, по оплате Минимальных платежей, Регулярных платежей и/или иных платежей. В указанный период Банк вправе приостановить начисление процентов и иных сумм, предусмотренных Договором кредитной карты.»"],
        "ground_truth": "Да, в документе указано, что по обращению клиента и по согласованию с банком возможно приостановление обязанности по погашению задолженности, выплате минимальных и регулярных платежей на срок от 1 до 12 месяцев. В этот период банк также может приостановить начисление процентов и других сумм по кредитной карте. Таким образом, вы можете получить льготный период для ремонта или других нужд, обратившись в банк с соответствующим заявлением."
    }
)

data.append(
    {
        "question": "Что происходит с депозитами клиента в случае его смерти?",
        "contexts": [
            "В случае смерти клиента банк замораживает депозиты до решения вопросов наследства в соответствии с законодательством."
        ],
        "ground_truth": "После смерти клиента банк замораживает все его депозиты и удерживает их до тех пор, пока не будут решены вопросы наследства в соответствии с действующим законодательством."
    }
)

data.append(
    {
        "question": "Могут ли клиенты изменять свой тарифный план по инициативе и как это отразится на их текущих услугах?",
        "contexts": [
            "Клиенты могут запросить изменение своего тарифного плана, однако любые изменения должны быть согласованы с банком и могут повлиять на условия их текущих услуг."
        ],
        "ground_truth": "Клиенты имеют право запросить изменение своего тарифного плана, но такие изменения должны быть согласованы с банком. Это может повлиять на условия предоставления текущих услуг в зависимости от нового тарифного плана."
    }
)

data.append(
    {
        "question": "Какие меры предпринимает банк для защиты личных данных клиентов?",
        "contexts": [
            "Банк применяет современные технологические и организационные меры для защиты личных данных клиентов от несанкционированного доступа, изменения, раскрытия или уничтожения."
        ],
        "ground_truth": "Банк использует различные современные технологические и организационные меры для обеспечения безопасности личных данных клиентов, что включает защиту от несанкционированного доступа, изменений, раскрытия информации или уничтожения данных."
    }
)


data.append(
    {
        "question": "Какие функции предлагает банковское мобильное приложение для управления расчетными картами?",
        "contexts": [
            "Мобильное приложение Банка позволяет клиентам проводить транзакции с расчетными картами, включая проверку баланса, оплату услуг, переводы между счетами и другие операции."
        ],
        "ground_truth": "Мобильное приложение банка предлагает множество функций для управления расчетными картами, включая возможность проверки баланса, оплаты услуг, осуществления переводов между счетами, а также выполнения других финансовых операций."
    }
)

data.append(
    {
        "question": "Какова процедура восстановления доступа к счету в случае потери аутентификационных данных?",
        "contexts": [
            "В случае потери или компрометации аутентификационных данных клиента, банк предоставляет процедуру для восстановления доступа, включая подтверждение личности и возможно, временную блокировку счета для обеспечения безопасности."
        ],
        "ground_truth": "Если клиент потерял аутентификационные данные, он должен пройти процедуру их восстановления, которая может включать подтверждение его личности и временную блокировку счета для предотвращения несанкционированного доступа."
    }
)

data.append(
    {
        "question": "Может ли клиент отказаться от получения уведомлений от банка и как это влияет на его обслуживание?",
        "contexts": [
            "Клиенты имеют право отказаться от получения определенных типов уведомлений от банка, однако это может повлиять на их способность получать своевременную информацию о изменениях условий, сбоях в системе или других важных обновлениях."
        ],
        "ground_truth": "Клиенты могут отказаться от получения определенных типов уведомлений от банка, но это может привести к тому, что они не будут получать важные обновления и информацию своевременно, что может повлиять на их способность управлять своими счетами и услугами эффективно."
    }
)

data.append(
    {
        "question": "Каковы условия предоставления залога при получении кредита и что происходит с предметом залога в случае невыполнения обязательств по кредиту?",
        "contexts": [
            "Предмет залога используется для обеспечения исполнения обязательств по кредитному договору. В случае неисполнения клиентом своих обязательств, банк имеет право реализовать предмет залога для покрытия задолженности."
        ],
        "ground_truth": "При получении кредита клиент может предоставить предмет залога, который используется банком в качестве обеспечения. Если клиент не выполняет свои обязательства по кредиту, банк имеет право реализовать этот предмет залога для покрытия возникшей задолженности."
    }
)

data.append(
    {
        "question": "Какие действия должен предпринять клиент, если обнаружит ложные транзакции по своему счету?",
        "contexts": [
            "В случае обнаружения неавторизованных или ошибочных транзакций на своем счету, клиент должен немедленно уведомить банк для проведения расследования и корректировки транзакций."
        ],
        "ground_truth": "Клиент должен незамедлительно связаться с банком и сообщить о любых неавторизованных или ошибочных транзакциях на своем счету. Банк затем проведет необходимое расследование и, при необходимости, выполнит корректировку транзакций."
    }
)

data.append(
    {
        "question": "Какие преимущества предлагает программа лояльности банка для держателей кредитных карт?",
        "contexts": [
            "Программа лояльности банка может включать бонусные баллы, скидки у партнеров банка и другие привилегии, которые могут быть использованы держателями кредитных карт для снижения стоимости покупок или получения эксклюзивных предложений."
        ],
        "ground_truth": "Программа лояльности банка предлагает держателям кредитных карт различные преимущества, такие как накопление бонусных баллов, получение скидок у партнеров банка и доступ к эксклюзивным предложениям, которые помогают снизить стоимость покупок и улучшить общий опыт использования карт."
    }
)



data.append(
    {
        "question": "Как клиенты могут увеличить лимит по своей кредитной карте?",
        "contexts": [
            "Для увеличения кредитного лимита клиенты должны подать заявление через мобильное приложение или веб-сайт банка, после чего банк рассмотрит их кредитную историю и текущую финансовую ситуацию."
        ],
        "ground_truth": "Чтобы увеличить кредитный лимит, клиентам необходимо подать соответствующее заявление через мобильное приложение или веб-сайт банка. Банк затем оценит их кредитную историю и текущую финансовую ситуацию перед принятием решения."
    }
)

data.append(
    {
        "question": "Какие меры безопасности при использовании банкоматов для снятия наличных?",
        "contexts": [
            "Для защиты клиентов при использовании банкоматов банк внедряет множество мер безопасности, включая шифрование данных, камеры наблюдения и системы предотвращения скимминга."
        ],
        "ground_truth": "Банк принимает различные меры безопасности при использовании банкоматов, такие как шифрование данных, установка камер наблюдения и внедрение систем предотвращения скимминга, чтобы защитить клиентов от мошенничества и краж."
    }
)

data.append(
    {
        "question": "Какие процедуры предусмотрены банком для обработки жалоб клиентов?",
        "contexts": [
            "Банк имеет установленные процедуры для обработки и рассмотрения жалоб клиентов, включая регистрацию жалобы, ее анализ и предоставление ответа клиенту в установленные сроки."
        ],
        "ground_truth": "Банк следует четко установленным процедурам для обработки жалоб клиентов, которые включают регистрацию жалобы, ее тщательный анализ и предоставление ответа клиенту в соответствии с установленными сроками."
    }
)

data.append(
    {
        "question": "Как клиент может активировать новую банковскую карту?",
        "contexts": [
            "Для активации новой банковской карты клиенту необходимо выполнить активацию через мобильное приложение банка или позвонить в службу поддержки для верификации своих данных."
        ],
        "ground_truth": "Для активации новой банковской карты клиент может использовать мобильное приложение банка или связаться с службой поддержки, где ему потребуется верифицировать свои личные данные для завершения процесса активации."
    }
)

data.append(
    {
        "question": "Какие услуги доступны клиентам через Интернет-банк?",
        "contexts": [
            "Через Интернет-банк клиенты могут управлять своими счетами, осуществлять платежи и переводы, а также получать детальную информацию о своих финансовых операциях."
        ],
        "ground_truth": "Интернет-банк предоставляет клиентам возможности управления их счетами, осуществления платежей и переводов, а также доступ к подробной информации о всех их финансовых операциях."
    }
)

data.append(
    {
        "question": "Каковы условия отмены банковской операции, например, перевода средств или платежа?",
        "contexts": [
            "Клиенты могут отменить определенные банковские операции, если они не были еще обработаны банком. Условия отмены операций установлены в пользовательском соглашении и зависят от типа операции."
        ],
        "ground_truth": "Условия отмены банковской операции зависят от того, была ли операция уже обработана банком. Для операций, которые еще не обработаны, клиенты могут инициировать отмену, следуя процедурам, описанным в пользовательском соглашении и в зависимости от типа операции."
    }
)

# %% [markdown]
# ## провдем проверку

# %%
import pandas as pd

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#                                             question  \
# 0                Можно ли не расписываться на карте?
# 1  Мой друг попросил меня дать свою карту для опл...
# 2  Можно ли передавать продавцу свою карту при оп...
# 3  Безопасно ли хранить пинкод в заметках в телеф...
# 4                                   Я потеряла карту
#
#                                             contexts  \
# 0  [После получения карты поставьте свою подпись ...
# 1  [Никогда не принимайте рекомендации, советы, п...
# 2  [Допускается передать карту при совершении опл...
# 3  [Категорически запрещается записывать ПИН-код ...
# 4  [ Вы потеряли карту или ее украли\nПрежде всег...
#
#                                         ground_truth
# 0  При отсутствии подписи карта может быть не при...
# 1  Не передавайте карту другим лицам, в т.ч. родс...
# 2  Да, можно в некоторых случаях, например, допус...
# 3  Да, однако не указывайте в названии заметки, ч...
# 4  Если вы не уверены, что карту украли, не спеши...

# %%
df.tail()
# Out:
#                                              question  \
# 85  Какие меры безопасности при использовании банк...
# 86  Какие процедуры предусмотрены банком для обраб...
# 87  Как клиент может активировать новую банковскую...
# 88  Какие услуги доступны клиентам через Интернет-...
# 89  Каковы условия отмены банковской операции, нап...
#
#                                              contexts  \
# 85  [Для защиты клиентов при использовании банкома...
# 86  [Банк имеет установленные процедуры для обрабо...
# 87  [Для активации новой банковской карты клиенту ...
# 88  [Через Интернет-банк клиенты могут управлять с...
# 89  [Клиенты могут отменить определенные банковски...
#
#                                          ground_truth
# 85  Банк принимает различные меры безопасности при...
# 86  Банк следует четко установленным процедурам дл...
# 87  Для активации новой банковской карты клиент мо...
# 88  Интернет-банк предоставляет клиентам возможнос...
# ...

# %%
df.to_csv('dataset_big.csv', index=False)
